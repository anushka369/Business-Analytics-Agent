# %% [markdown]
# # Creating Swarm of agents using Strands Agents

# %% [markdown]
# ## Understanding Swarm Multi-Agent Systems
#
# A Swarm is a collaborative agent orchestration system where multiple agents work together as a team to solve complex tasks. Unlike traditional sequential or hierarchical multi-agent systems, a Swarm enables autonomous coordination between agents with shared context and working memory.
#
# * **Self-organizing agent teams** with shared working memory
# * **Tool-based coordination** between agents
# * **Autonomous agent collaboration** without central control
# * **Dynamic task distribution** based on agent capabilities
# * **Collective intelligence** through shared context
# * **Multi-modal input support** for handling text, images, and other content types
#
# ## How Swarms Work
#
# Swarms operate on the principle of emergent intelligence - the idea that a group of specialized agents working together can solve problems more effectively than a single agent. Each agent in a Swarm:
#
# 1. Has access to the full task context
# 2. Can see the history of which agents have worked on the task
# 3. Can access shared knowledge contributed by other agents
# 4. Can decide when to hand off to another agent with different expertise

# %% [markdown]
# ## 1. Quick Start with Swarm tool

# %% [markdown]
# The Strands Agents SDK provides a built-in swarm tool that simplifies the implementation of multi-agent systems, offering a quick start for users. This tool implements a flexible swarm intelligence system with autonomous coordination between specialized agents.
#
# In this example:
# 1. The agent uses the swarm tool to dynamically create a team of specialized agents. These might include a researcher, an analyst, and a technical writer
# 2. Next the agent executes the swarm
# 3. The swarm agents collaborate autonomously, handing off to each other as needed
# 4. The agent analyzes the swarm results and provides a comprehensive response to the user

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: strands-agents-tools in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 2)) (0.2.18)
# Requirement already satisfied: strands-agents[a2a] in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 1)) (1.20.0)
# Requirement already satisfied: boto3<2.0.0,>=1.26.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents[a2a]->-r requirements.txt (line 1)) (1.42.11)
# Requirement already satisfied: botocore<2.0.0,>=1.29.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents[a2a]->-r requirements.txt (line 1)) (1.42.11)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in /opt/conda/lib/python3.12/site-packages (from strands-agents[a2a]->-r requirements.txt (line 1)) (0.17.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents[a2a]->-r requirements.txt (line 1)) (4.25.1)
# Requirement already satisfied: mcp<2.0.0,>=1.11.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents[a2a]->-r requirements.txt (line 1)) (1.24.0)
# Requirement already satisfied: opentelemetry-api<2.0.0,>=1.30.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents[a2a]->-r requirements.txt (line 1)) (1.39.1)
# Requirement already satisfied: opentelemetry-instrumentation-threading<1.00b0,>=0.51b0 in /opt/conda/lib/python3.12/site-packages (from strands-agents[a2a]->-r requirements.txt (line 1)) (0.60b1)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.30.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents[a2a]->-r requirements.txt (line 1)) (1.39.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.4.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents[a2a]->-r requirements.txt (line 1)) (2.12.5)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.13.2 in /opt/conda/lib/python3.12/site-packages (from strands-agents[a2a]->-r requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: watchdog<7.0.0,>=6.0.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents[a2a]->-r requirements.txt (line 1)) (6.0.0)
# Requirement already satisfied: a2a-sdk<0.4.0,>=0.3.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents[a2a]->-r requirements.txt (line 1)) (0.3.22)
# Requirement already satisfied: fastapi<1.0.0,>=0.115.12 in /opt/conda/lib/python3.12/site-packages (from strands-agents[a2a]->-r requirements.txt (line 1)) (0.121.1)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /opt/conda/lib/python3.12/site-packages (from strands-agents[a2a]->-r requirements.txt (line 1)) (0.28.1)
# Requirement already satisfied: starlette<1.0.0,>=0.46.2 in /opt/conda/lib/python3.12/site-packages (from strands-agents[a2a]->-r requirements.txt (line 1)) (0.49.3)
# Requirement already satisfied: uvicorn<1.0.0,>=0.34.2 in /opt/conda/lib/python3.12/site-packages (from strands-agents[a2a]->-r requirements.txt (line 1)) (0.38.0)
# Requirement already satisfied: google-api-core>=1.26.0 in /opt/conda/lib/python3.12/site-packages (from a2a-sdk<0.4.0,>=0.3.0->strands-agents[a2a]->-r requirements.txt (line 1)) (2.28.1)
# Requirement already satisfied: httpx-sse>=0.4.0 in /opt/conda/lib/python3.12/site-packages (from a2a-sdk<0.4.0,>=0.3.0->strands-agents[a2a]->-r requirements.txt (line 1)) (0.4.3)
# Requirement already satisfied: protobuf>=5.29.5 in /opt/conda/lib/python3.12/site-packages (from a2a-sdk<0.4.0,>=0.3.0->strands-agents[a2a]->-r requirements.txt (line 1)) (6.33.2)
# Requirement already satisfied: sqlalchemy>=2.0.0 in /opt/conda/lib/python3.12/site-packages (from sqlalchemy[aiomysql,asyncio]>=2.0.0; extra == "sql"->a2a-sdk[sql]<0.4.0,>=0.3.0; extra == "a2a"->strands-agents[a2a]->-r requirements.txt (line 1)) (2.0.45)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.12/site-packages (from boto3<2.0.0,>=1.26.0->strands-agents[a2a]->-r requirements.txt (line 1)) (1.0.1)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in /opt/conda/lib/python3.12/site-packages (from boto3<2.0.0,>=1.26.0->strands-agents[a2a]->-r requirements.txt (line 1)) (0.16.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/lib/python3.12/site-packages (from botocore<2.0.0,>=1.29.0->strands-agents[a2a]->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /opt/conda/lib/python3.12/site-packages (from botocore<2.0.0,>=1.29.0->strands-agents[a2a]->-r requirements.txt (line 1)) (2.6.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in /opt/conda/lib/python3.12/site-packages (from fastapi<1.0.0,>=0.115.12->strands-agents[a2a]->-r requirements.txt (line 1)) (0.0.4)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.12/site-packages (from httpx<1.0.0,>=0.28.1->strands-agents[a2a]->-r requirements.txt (line 1)) (4.12.0)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.12/site-packages (from httpx<1.0.0,>=0.28.1->strands-agents[a2a]->-r requirements.txt (line 1)) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.12/site-packages (from httpx<1.0.0,>=0.28.1->strands-agents[a2a]->-r requirements.txt (line 1)) (1.0.9)
# Requirement already satisfied: idna in /opt/conda/lib/python3.12/site-packages (from httpx<1.0.0,>=0.28.1->strands-agents[a2a]->-r requirements.txt (line 1)) (3.11)
# Requirement already satisfied: h11>=0.16 in /opt/conda/lib/python3.12/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->strands-agents[a2a]->-r requirements.txt (line 1)) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents[a2a]->-r requirements.txt (line 1)) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents[a2a]->-r requirements.txt (line 1)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents[a2a]->-r requirements.txt (line 1)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents[a2a]->-r requirements.txt (line 1)) (0.30.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents[a2a]->-r requirements.txt (line 1)) (2.12.0)
# Requirement already satisfied: pyjwt>=2.10.1 in /opt/conda/lib/python3.12/site-packages (from pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.11.0->strands-agents[a2a]->-r requirements.txt (line 1)) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents[a2a]->-r requirements.txt (line 1)) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents[a2a]->-r requirements.txt (line 1)) (3.0.4)
# Requirement already satisfied: typing-inspection>=0.4.1 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents[a2a]->-r requirements.txt (line 1)) (0.4.2)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-api<2.0.0,>=1.30.0->strands-agents[a2a]->-r requirements.txt (line 1)) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /opt/conda/lib/python3.12/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<2.0.0,>=1.30.0->strands-agents[a2a]->-r requirements.txt (line 1)) (3.23.0)
# Requirement already satisfied: opentelemetry-instrumentation==0.60b1 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents[a2a]->-r requirements.txt (line 1)) (0.60b1)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents[a2a]->-r requirements.txt (line 1)) (1.17.3)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation==0.60b1->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents[a2a]->-r requirements.txt (line 1)) (0.60b1)
# Requirement already satisfied: packaging>=18.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation==0.60b1->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents[a2a]->-r requirements.txt (line 1)) (25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.4.0->strands-agents[a2a]->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/conda/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.4.0->strands-agents[a2a]->-r requirements.txt (line 1)) (2.41.5)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<2.0.0,>=1.29.0->strands-agents[a2a]->-r requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: click>=7.0 in /opt/conda/lib/python3.12/site-packages (from uvicorn<1.0.0,>=0.34.2->strands-agents[a2a]->-r requirements.txt (line 1)) (8.3.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (3.13.2)
# Requirement already satisfied: aws-requests-auth<0.5.0,>=0.4.3 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (0.4.3)
# Requirement already satisfied: dill<0.5.0,>=0.4.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (0.4.0)
# Requirement already satisfied: markdownify<2.0.0,>=1.0.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (1.2.2)
# Requirement already satisfied: pillow<12.0.0,>=11.2.1 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (11.3.0)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.51 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (3.0.52)
# Requirement already satisfied: requests<3.0.0,>=2.28.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (2.32.5)
# Requirement already satisfied: rich<15.0.0,>=14.0.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (14.2.0)
# Requirement already satisfied: slack-bolt<2.0.0,>=1.23.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (1.25.0)
# Requirement already satisfied: sympy<2.0.0,>=1.12.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (1.14.0)
# Requirement already satisfied: tenacity<10.0.0,>=9.1.2 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (9.1.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (1.22.0)
# Requirement already satisfied: beautifulsoup4<5,>=4.9 in /opt/conda/lib/python3.12/site-packages (from markdownify<2.0.0,>=1.0.0->strands-agents-tools->-r requirements.txt (line 2)) (4.14.2)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.12/site-packages (from beautifulsoup4<5,>=4.9->markdownify<2.0.0,>=1.0.0->strands-agents-tools->-r requirements.txt (line 2)) (2.8)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.12/site-packages (from prompt-toolkit<4.0.0,>=3.0.51->strands-agents-tools->-r requirements.txt (line 2)) (0.2.14)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests<3.0.0,>=2.28.0->strands-agents-tools->-r requirements.txt (line 2)) (3.4.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.12/site-packages (from rich<15.0.0,>=14.0.0->strands-agents-tools->-r requirements.txt (line 2)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.12/site-packages (from rich<15.0.0,>=14.0.0->strands-agents-tools->-r requirements.txt (line 2)) (2.19.2)
# Requirement already satisfied: slack_sdk<4,>=3.35.0 in /opt/conda/lib/python3.12/site-packages (from slack-bolt<2.0.0,>=1.23.0->strands-agents-tools->-r requirements.txt (line 2)) (3.37.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.12/site-packages (from sympy<2.0.0,>=1.12.0->strands-agents-tools->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /opt/conda/lib/python3.12/site-packages (from google-api-core>=1.26.0->a2a-sdk<0.4.0,>=0.3.0->strands-agents[a2a]->-r requirements.txt (line 1)) (1.72.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /opt/conda/lib/python3.12/site-packages (from google-api-core>=1.26.0->a2a-sdk<0.4.0,>=0.3.0->strands-agents[a2a]->-r requirements.txt (line 1)) (1.26.1)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /opt/conda/lib/python3.12/site-packages (from google-api-core>=1.26.0->a2a-sdk<0.4.0,>=0.3.0->strands-agents[a2a]->-r requirements.txt (line 1)) (2.43.0)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /opt/conda/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core>=1.26.0->a2a-sdk<0.4.0,>=0.3.0->strands-agents[a2a]->-r requirements.txt (line 1)) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core>=1.26.0->a2a-sdk<0.4.0,>=0.3.0->strands-agents[a2a]->-r requirements.txt (line 1)) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core>=1.26.0->a2a-sdk<0.4.0,>=0.3.0->strands-agents[a2a]->-r requirements.txt (line 1)) (4.7.2)
# Requirement already satisfied: pyasn1>=0.1.3 in /opt/conda/lib/python3.12/site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.14.1->google-api-core>=1.26.0->a2a-sdk<0.4.0,>=0.3.0->strands-agents[a2a]->-r requirements.txt (line 1)) (0.6.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich<15.0.0,>=14.0.0->strands-agents-tools->-r requirements.txt (line 2)) (0.1.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /opt/conda/lib/python3.12/site-packages (from pydantic-settings>=2.5.2->mcp<2.0.0,>=1.11.0->strands-agents[a2a]->-r requirements.txt (line 1)) (1.2.1)
# Requirement already satisfied: cryptography>=3.4.0 in /opt/conda/lib/python3.12/site-packages (from pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.11.0->strands-agents[a2a]->-r requirements.txt (line 1)) (46.0.3)
# Requirement already satisfied: cffi>=2.0.0 in /opt/conda/lib/python3.12/site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.11.0->strands-agents[a2a]->-r requirements.txt (line 1)) (2.0.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.11.0->strands-agents[a2a]->-r requirements.txt (line 1)) (2.23)
# Requirement already satisfied: greenlet>=1 in /opt/conda/lib/python3.12/site-packages (from sqlalchemy>=2.0.0->sqlalchemy[aiomysql,asyncio]>=2.0.0; extra == "sql"->a2a-sdk[sql]<0.4.0,>=0.3.0; extra == "a2a"->strands-agents[a2a]->-r requirements.txt (line 1)) (3.3.0)
# Requirement already satisfied: aiomysql>=0.2.0 in /opt/conda/lib/python3.12/site-packages (from sqlalchemy[aiomysql,asyncio]>=2.0.0; extra == "sql"->a2a-sdk[sql]<0.4.0,>=0.3.0; extra == "a2a"->strands-agents[a2a]->-r requirements.txt (line 1)) (0.3.2)
# Requirement already satisfied: PyMySQL>=1.0 in /opt/conda/lib/python3.12/site-packages (from aiomysql>=0.2.0->sqlalchemy[aiomysql,asyncio]>=2.0.0; extra == "sql"->a2a-sdk[sql]<0.4.0,>=0.3.0; extra == "a2a"->strands-agents[a2a]->-r requirements.txt (line 1)) (1.1.2)
# Requirement already satisfied: aiosqlite in /opt/conda/lib/python3.12/site-packages (from sqlalchemy[aiosqlite,asyncio]>=2.0.0; extra == "sql"->a2a-sdk[sql]<0.4.0,>=0.3.0; extra == "a2a"->strands-agents[a2a]->-r requirements.txt (line 1)) (0.19.0)
# Requirement already satisfied: asyncpg in /opt/conda/lib/python3.12/site-packages (from sqlalchemy[asyncio,postgresql-asyncpg]>=2.0.0; extra == "sql"->a2a-sdk[sql]<0.4.0,>=0.3.0; extra == "a2a"->strands-agents[a2a]->-r requirements.txt (line 1)) (0.31.0)

# %%
from strands import Agent
from strands_tools import swarm

# %% [markdown]
# ## 1.1 Swarm as a Tool

# %%
# Agent initialization
agent = Agent(model="us.anthropic.claude-3-7-sonnet-20250219-v1:0",tools=[swarm])

# Invocation through natural language
result = str(agent(
    "Use a swarm of 4 agents to analyze the current market trend for generative ai based agents."
))
# Out:
# I'll help you analyze the current market trend for generative AI-based agents using a swarm of specialized AI agents. Each agent will focus on a different aspect of the market analysis to provide a comprehensive overview.
#
# Let me set up a swarm with 4 specialized agents:
# Tool #1: swarm
# I'll provide a comprehensive analysis of the current market trends for generative AI-based agents. Let me break this down into key areas based on the latest market data and trends.
#
# ## Market Size and Growth Projections
#
# The generative AI agent market is experiencing explosive growth:
#
# **Current Market Size (2024):**
# - Global generative AI market: ~$44-50 billion
# - AI agent-specific segment: ~$8-12 billion
# - Expected to reach $280-400 billion by 2030
#
# **Growth Drivers:**
# - CAGR of 35-45% through 2030
# - Enterprise adoption accelerating post-ChatGPT breakthrough
# - Venture capital investment exceeding $25 billion in 2023-2024
#
# ## Key Market Players and Competitive Landscape
#
# **Tier 1 Leaders:**
# - **OpenAI**: GPT-4/ChatGPT dominance, enterprise solutions
# - **Microsoft**: Copilot integration across Office suite, Azure AI
# - **Google**: Bard/Gemini, enterprise AI tools
# - **Anthropic**: Claude family, safety-focused approach
#
# **Emerging Competitors:**
# - **Cohere**: Enterprise-focused language models
# - **Stability AI**: Open-source generative models
# - **Inflection AI**: Personal AI assistant Pi
# - **Character.AI**: Consumer conversational agents
#
# **Market Share Distribution:**
# - OpenAI: ~30-35% market share
# - Microsoft: ~20-25%
# - Google: ~15-20%
# - Others: ~20-30%
#
# ## Investment and Funding Trends
#
# **2023-2024 Investment Highlights:**
# - Total AI investment: $67+ billion
# - Generative AI: ~40% of total AI investments
# - Notable rounds: Anthropic ($4B), Inflection AI ($1.3B)
# - Corporate investments: Microsoft-OpenAI partnership ($10B+)
#
# **Investor Focus Areas:**
# - Enterprise productivity tools
# - Vertical-specific AI agents
# - AI infrastructure and tooling
# - Multimodal capabilities
#
# ## Market Segmentation Analysis
#
# **By Application:**
# 1. **Customer Service Agents** (25% market share)
# 2. **Content Creation** (20%)
# 3. **Code Generation** (18%)
# 4. **Data Analysis** (15%)
# 5. **Personal Assistants** (12%)
# 6. **Other Enterprise Applications** (10%)
#
# **By Industry Vertical:**
# - Technology/Software: 35%
# - Financial Services: 20%
# - Healthcare: 15%
# - Retail/E-commerce: 12%
# - Media/Entertainment: 8%
# - Others: 10%
#
# ## Current Market Challenges
#
# **Technical Challenges:**
# - Hallucination and accuracy concerns
# - Context length limitations
# - Integration complexity
# - Computational costs
#
# **Business Challenges:**
# - ROI measurement difficulties
# - Skills gap in implementation
# - Regulatory uncertainty
# - Data privacy concerns
#
# **Market Adoption Barriers:**
# - High implementation costs
# - Change management resistance
# - Lack of standardization
# - Quality control issues
#
# ## Economic Impact Assessment
#
# **Productivity Gains:**
# - Estimated 20-40% efficiency improvements in knowledge work
# - $4.4 trillion potential annual economic impact (McKinsey)
# - Job transformation rather than replacement in most sectors
#
# **Cost Structure:**
# - Training costs: $100M+ for frontier models
# - Inference costs declining ~50% annually
# - Enterprise deployment: $50K-$2M+ per implementation
#
# This analysis covers the foundational market research aspects. For deeper insights into specific technical capabilities or industry applications, I can collaborate with my specialist colleagues. Would you like me to hand off to the tech specialist for more technical depth, or to the industry applications expert for sector-specific analysis?
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# # Current Market Analysis: Generative AI-based Agents
#
# ## Executive Summary
#
# The generative AI agent market is experiencing explosive growth, characterized by rapid innovation, significant investment, and expanding use cases across industries. This comprehensive analysis examines current trends, key players, market dynamics, and future directions in this transformative space.
#
# ## Market Size and Growth
#
# - **Current Market Valuation**: The global generative AI market is valued at approximately $13-17 billion in 2024, with AI agents representing a rapidly growing segment.
# - **Projected Growth**: The market for generative AI agents is expected to grow at a CAGR of 30-35% through 2030, potentially reaching $100+ billion.
# - **Investment Landscape**: Venture capital funding for generative AI startups focused on agents exceeded $20 billion in the past 18 months, with a significant acceleration in late 2023 and early 2024.
#
# ## Key Players and Competitive Landscape
#
# ### Established Leaders:
# - **OpenAI**: Leading with GPT-4 and assistant APIs, enabling sophisticated agent development.
# - **Anthropic**: Claude models with strong reasoning and instruction-following capabilities.
# - **Google/DeepMind**: Gemini models and agent frameworks for enterprise applications.
# - **Microsoft**: Copilot and Azure AI services offering enterprise-grade agent capabilities.
#
# ### Emerging Players:
# - **Adept AI**: Specialized in action-oriented AI agents with their ACT-1 model.
# - **Cohere**: Focusing on enterprise-ready conversational and reasoning agents.
# - **Replit**: Building coding and development-focused AI agents.
# - **Fixie.ai**: Creating specialized agent platforms for businesses.
# - **Langchain, LlamaIndex, AutoGPT**: Offering frameworks for building custom agents.
#
# ## Technological Landscape
#
# - **Foundation Models**: Most agents are built on advanced LLMs (GPT-4, Claude, Gemini, etc.) with increasing capabilities.
# - **Multimodal Integration**: Growing trend toward agents that can process and generate text, images, audio, and video.
# - **Tool Use**: Enhanced capability to use external tools, APIs, and databases is a key advancement.
# - **Memory Systems**: Improved context retention and information retrieval systems.
# - **Reasoning Capabilities**: Progress in planning, problem decomposition, and self-correction.
# - **Agent Orchestration**: Systems for managing multiple agents working together (agent swarms).
#
# ## Industry Applications and Use Cases
#
# ### Enterprise Adoption:
# - **Customer Service**: Autonomous support agents handling complex customer inquiries.
# - **Productivity**: Digital assistants for scheduling, email management, and information retrieval.
# - **Content Creation**: Agents for generating marketing materials, reports, and creative content.
# - **Software Development**: Coding assistants and testing agents accelerating development cycles.
#
# ### Industry-Specific Applications:
# - **Healthcare**: Clinical documentation, research assistance, and patient engagement.
# - **Finance**: Market analysis, document processing, and personalized financial advice.
# - **Retail**: Shopping assistants, inventory management, and personalized recommendations.
# - **Legal**: Document review, contract analysis, and legal research.
# - **Education**: Personalized tutoring, curriculum development, and administrative support.
#
# ## Key Trends and Future Directions
#
# 1. **Autonomous Agency**: Increased capability for independent decision-making and action.
# 2. **Specialized Agents**: Growing trend toward purpose-built agents for specific domains.
# 3. **Agent Collaboration**: Systems enabling multiple agents to work together on complex tasks.
# 4. **Personal AI Assistants**: Rise of personalized agents that adapt to individual users.
# 5. **Embedded Agents**: Integration into everyday applications and platforms.
# 6. **Regulatory Attention**: Increasing focus on governance, transparency, and safety measures.
#
# ## Challenges and Considerations
#
# - **Trust and Safety**: Ensuring reliable, safe operation without harmful outputs.
# - **Privacy Concerns**: Managing sensitive data access and usage.
# - **Performance Limitations**: Current agents still struggle with complex reasoning and planning.
# - **Integration Challenges**: Technical difficulties in connecting to existing systems.
# - **Cost Considerations**: Computational resources required for advanced agents remain significant.
# - **Ethical Considerations**: Questions around autonomy, disclosure, and appropriate use cases.
#
# ## Conclusion
#
# The generative AI agent market is at an inflection point, moving from early experimental applications toward mainstream adoption across industries. While technological challenges remain, the rapid pace of innovation suggests continued growth and expanding capabilities. Organizations are increasingly viewing AI agents as strategic assets rather than experimental technologies, indicating a maturing market with significant long-term potential.

# %%
print(result)
# Out:
# # Current Market Analysis: Generative AI-based Agents
#
# ## Executive Summary
#
# The generative AI agent market is experiencing explosive growth, characterized by rapid innovation, significant investment, and expanding use cases across industries. This comprehensive analysis examines current trends, key players, market dynamics, and future directions in this transformative space.
#
# ## Market Size and Growth
#
# - **Current Market Valuation**: The global generative AI market is valued at approximately $13-17 billion in 2024, with AI agents representing a rapidly growing segment.
# - **Projected Growth**: The market for generative AI agents is expected to grow at a CAGR of 30-35% through 2030, potentially reaching $100+ billion.
# - **Investment Landscape**: Venture capital funding for generative AI startups focused on agents exceeded $20 billion in the past 18 months, with a significant acceleration in late 2023 and early 2024.
#
# ## Key Players and Competitive Landscape
#
# ### Established Leaders:
# - **OpenAI**: Leading with GPT-4 and assistant APIs, enabling sophisticated agent development.
# - **Anthropic**: Claude models with strong reasoning and instruction-following capabilities.
# - **Google/DeepMind**: Gemini models and agent frameworks for enterprise applications.
# - **Microsoft**: Copilot and Azure AI services offering enterprise-grade agent capabilities.
#
# ### Emerging Players:
# - **Adept AI**: Specialized in action-oriented AI agents with their ACT-1 model.
# - **Cohere**: Focusing on enterprise-ready conversational and reasoning agents.
# - **Replit**: Building coding and development-focused AI agents.
# - **Fixie.ai**: Creating specialized agent platforms for businesses.
# - **Langchain, LlamaIndex, AutoGPT**: Offering frameworks for building custom agents.
#
# ## Technological Landscape
#
# - **Foundation Models**: Most agents are built on advanced LLMs (GPT-4, Claude, Gemini, etc.) with increasing capabilities.
# - **Multimodal Integration**: Growing trend toward agents that can process and generate text, images, audio, and video.
# - **Tool Use**: Enhanced capability to use external tools, APIs, and databases is a key advancement.
# - **Memory Systems**: Improved context retention and information retrieval systems.
# - **Reasoning Capabilities**: Progress in planning, problem decomposition, and self-correction.
# - **Agent Orchestration**: Systems for managing multiple agents working together (agent swarms).
#
# ## Industry Applications and Use Cases
#
# ### Enterprise Adoption:
# - **Customer Service**: Autonomous support agents handling complex customer inquiries.
# - **Productivity**: Digital assistants for scheduling, email management, and information retrieval.
# - **Content Creation**: Agents for generating marketing materials, reports, and creative content.
# - **Software Development**: Coding assistants and testing agents accelerating development cycles.
#
# ### Industry-Specific Applications:
# - **Healthcare**: Clinical documentation, research assistance, and patient engagement.
# - **Finance**: Market analysis, document processing, and personalized financial advice.
# - **Retail**: Shopping assistants, inventory management, and personalized recommendations.
# - **Legal**: Document review, contract analysis, and legal research.
# - **Education**: Personalized tutoring, curriculum development, and administrative support.
#
# ## Key Trends and Future Directions
#
# 1. **Autonomous Agency**: Increased capability for independent decision-making and action.
# 2. **Specialized Agents**: Growing trend toward purpose-built agents for specific domains.
# 3. **Agent Collaboration**: Systems enabling multiple agents to work together on complex tasks.
# 4. **Personal AI Assistants**: Rise of personalized agents that adapt to individual users.
# 5. **Embedded Agents**: Integration into everyday applications and platforms.
# 6. **Regulatory Attention**: Increasing focus on governance, transparency, and safety measures.
#
# ## Challenges and Considerations
#
# - **Trust and Safety**: Ensuring reliable, safe operation without harmful outputs.
# - **Privacy Concerns**: Managing sensitive data access and usage.
# - **Performance Limitations**: Current agents still struggle with complex reasoning and planning.
# - **Integration Challenges**: Technical difficulties in connecting to existing systems.
# - **Cost Considerations**: Computational resources required for advanced agents remain significant.
# - **Ethical Considerations**: Questions around autonomy, disclosure, and appropriate use cases.
#
# ## Conclusion
#
# The generative AI agent market is at an inflection point, moving from early experimental applications toward mainstream adoption across industries. While technological challenges remain, the rapid pace of innovation suggests continued growth and expanding capabilities. Organizations are increasingly viewing AI agents as strategic assets rather than experimental technologies, indicating a maturing market with significant long-term potential.

# %% [markdown]
# The swarm tool implements a flexible swarm intelligence system built on the Strands SDK's native Swarm multi-agent pattern. This system enables users to define custom teams of specialized AI agents that collaborate autonomously through shared context and tool-based coordination.
#
# **Key Features:**
# - **Custom Agent Teams**: User-defined agent specifications with individual system prompts, per-agent tool configuration, and model settings
# - **Autonomous Coordination**: Built-in coordination tools (handoff_to_agent, complete_swarm_task) with shared working memory across all agents
# - **Advanced Configuration**: Individual model providers and settings per agent, customizable tool access, comprehensive timeout and safety mechanisms
# - **Emergent Collective Intelligence**: Agents autonomously decide when to collaborate or handoff, with dynamic task distribution based on capabilities
#
# The full implementation of the swarm tool can be found in the [Strands Tools repository](https://github.com/strands-agents/tools/blob/main/src/strands_tools/swarm.py).
#
# **Key Parameters:**
# - `task`: The main task to be processed by the swarm
# - `agents`: List of agent specifications with name, system_prompt, tools, model_provider, and model_settings
# - `max_handoffs`: Maximum number of agent handoffs allowed (default: 20)
# - `max_iterations`: Maximum total iterations across all agents (default: 20)
# - `execution_timeout`: Total execution timeout in seconds (default: 900.0)
# - `node_timeout`: Individual agent timeout in seconds (default: 300.0)
# - `repetitive_handoff_detection_window`: Number of recent nodes to check for ping-pong behavior
# - `repetitive_handoff_min_unique_agents`: Minimum unique nodes required in recent sequence
#
# **How the Swarm Tool Works:**
# 1. **Agent Creation**: Creates specialized agents based on user specifications with individual model providers and tools
# 2. **Swarm Initialization**: Sets up the Strands SDK Swarm with coordination tools and safety mechanisms
# 3. **Autonomous Execution**: Agents collaborate through handoffs and shared context without central control
# 4. **Result Aggregation**: Collects individual contributions and provides comprehensive execution metrics

# %% [markdown]
# ## 2. Creating a Swarm with Strands Agents

# %% [markdown]
# Strands Agents SDK allows you to create swarms using existing Agent objects, even when they use different model providers or have different configurations. The Swarm system enables autonomous coordination between agents through auto handoff mechanisms and shared context, allowing agents to dynamically transfer control when they need specialized expertise from other agents.
#
# ### 2.1 Agent Coordination with Auto Handoff

# %% [markdown]
# <p align="center">
#     <img src="./images/swarm_example.png">
# </p>

# %% [markdown]
# In this coordination approach, agents use the Strands SDK's native Swarm pattern with built-in handoff tools to autonomously transfer control to other specialized agents when they need different expertise. Each agent is automatically equipped with coordination tools like `handoff_to_agent` and `complete_swarm_task`. The following example demonstrates a swarm of specialized agents collaborating through shared context and autonomous handoffs:

# %%
# Create specialized agents with different expertise
research_agent = Agent(system_prompt=("""You are a Research Agent specializing in gathering and analyzing information.
Your role in the swarm is to provide factual information and research insights on the topic.
You should focus on providing accurate data and identifying key aspects of the problem.
When receiving input from other agents, evaluate if their information aligns with your research.
"""), 
name="research_agent",model="us.anthropic.claude-3-7-sonnet-20250219-v1:0")

creative_agent = Agent(system_prompt=("""You are a Creative Agent specializing in generating innovative solutions.
Your role in the swarm is to think outside the box and propose creative approaches.
You should build upon information from other agents while adding your unique creative perspective.
Focus on novel approaches that others might not have considered.
"""), 
name="creative_agent",model="us.anthropic.claude-3-7-sonnet-20250219-v1:0")

critical_agent = Agent(system_prompt=("""You are a Critical Agent specializing in analyzing proposals and finding flaws.
Your role in the swarm is to evaluate solutions proposed by other agents and identify potential issues.
You should carefully examine proposed solutions, find weaknesses or oversights, and suggest improvements.
Be constructive in your criticism while ensuring the final solution is robust.
"""), 
name="critical_agent",model="us.anthropic.claude-3-7-sonnet-20250219-v1:0")

summarizer_agent = Agent(system_prompt=("""You are a Summarizer Agent specializing in synthesizing information.
Your role in the swarm is to gather insights from all agents and create a cohesive final solution.
You should combine the best ideas and address the criticisms to create a comprehensive response.
Focus on creating a clear, actionable summary that addresses the original query effectively.
"""),name="summarizer_agent",model="us.anthropic.claude-3-7-sonnet-20250219-v1:0")

# %% [markdown]
# The agent coordination is implemented using the Strands SDK's native Swarm class, which automatically provides coordination tools and manages shared context:

# %%
from strands.multiagent import Swarm

# Create a swarm with these agents
swarm = Swarm(
    [research_agent, creative_agent, critical_agent, summarizer_agent],
    max_handoffs=20,
    max_iterations=20,
    execution_timeout=900.0,  # 15 minutes
    node_timeout=300.0,       # 5 minutes per agent
    repetitive_handoff_detection_window=8,  # There must be >= 3 unique agents in the last 8 handoffs
    repetitive_handoff_min_unique_agents=3
)

# %% [markdown]
# The swarm operates through autonomous agent coordination, with agents deciding when to handoff based on their expertise and the task requirements:

# %%
# Execute the swarm on a task
result = swarm("Create a blog post explaining Agentic AI then create a summary for a social media post.")
# Out:
# I'll help gather information about Agentic AI for this blog post. Since this requires both research-based content followed by creative writing and summarization, I'll need to collaborate with the appropriate agents in our swarm.
#
# For this request, I should first provide factual information about Agentic AI, then hand off to the Creative Agent to craft the actual blog post, followed by the Summarizer Agent who can create the social media summary.
# Tool #1: handoff_to_agent
# I've handed off the request to the creative_agent with comprehensive research information about Agentic AI. The creative_agent will craft a blog post using the factual foundation I provided, covering the definition, key characteristics, evolution from traditional AI, applications, technical foundations, and important challenges related to Agentic AI.
#
# After creating the blog post, the creative_agent has been instructed to hand off to the summarizer_agent, who will create a condensed version suitable for social media platforms.
#
# This collaborative approach ensures that you'll receive both an informative, well-researched blog post and an engaging social media summary about Agentic AI.I'll create a creative and engaging blog post about Agentic AI based on the key facts provided. I'll focus on making this informative yet accessible with some creative metaphors and examples.
#
# # The Dawn of Agentic AI: When Artificial Intelligence Takes the Wheel
#
# ## Introduction
#
# Imagine having a digital twin who not only understands your requests but anticipates your needs, makes decisions on your behalf, and learns from every interaction to serve you better tomorrow. This isn't science fiction—it's the emerging world of Agentic AI, a paradigm shift that's redefining our relationship with technology.
#
# ## What Exactly is Agentic AI?
#
# Agentic AI represents the next evolutionary leap in artificial intelligence—systems that don't just respond but act autonomously on your behalf. Unlike the reactive AI assistants we've grown accustomed to, these digital agents can formulate plans, make decisions, and execute complex sequences of actions to accomplish goals you've set.
#
# Think of traditional AI as a sophisticated calculator—immensely powerful but ultimately passive, waiting for your next command. Agentic AI, by contrast, is more like hiring a personal assistant who not only follows instructions but uses initiative and judgment to get things done even when you're not micromanaging every step.
#
# ## The Five Pillars of Agentic Intelligence
#
# What separates a true AI agent from other systems? Five core characteristics define this new breed of artificial intelligence:
#
# 1. **Goal-Directed Planning**: Agents don't just respond—they strategize. When you ask an agentic system to plan your vacation, it doesn't just search for flights; it creates a comprehensive itinerary considering your preferences, budget constraints, and logistical efficiency.
#
# 2. **Autonomous Decision-Making**: Within defined parameters, agentic AI makes judgment calls without constant human oversight. Your digital financial advisor might rebalance your portfolio when market conditions change, making decisions based on your pre-established risk tolerance and goals.
#
# 3. **Learning and Adaptation**: These systems evolve through experience. Your agentic kitchen assistant remembers that you prefer recipes with less salt or that you typically cook vegetarian on Mondays, refining its suggestions without explicit reprogramming.
#
# 4. **System Interaction**: Agents don't operate in isolation—they coordinate with other digital services and systems. Your scheduling agent might communicate with your colleague's calendar, your preferred restaurant booking system, and your rideshare app to orchestrate a perfect business lunch.
#
# 5. **Persistent Memory**: Unlike stateless chatbots that forget you between sessions, agentic AI maintains continuity across interactions, building a progressive understanding of your preferences, habits, and goals.
#
# ## From Reactive to Proactive: The AI Evolution
#
# The shift from traditional to agentic AI mirrors our own cognitive development. Children first learn to respond to direct questions, but as they mature, they develop the ability to plan ahead, make autonomous decisions, and anticipate needs.
#
# Traditional AI excels at specific tasks: recognizing images, generating text, or answering questions. But these systems fundamentally remain reactive—waiting for human prompts before springing into action.
#
# Agentic AI represents a cognitive leap forward. When you tell your agentic home assistant you're hosting a dinner party next Friday, it might proactively suggest menu options based on guests' dietary restrictions, create a shopping list, adjust your thermostat schedule for that evening, and even queue up an appropriate playlist—all without separate commands for each task.
#
# ## Agentic AI in Action: Four Transformative Applications
#
# ### The Personal Life Coordinator
#
# Imagine a digital assistant that doesn't just remind you about appointments but actively manages your schedule—rescheduling the dentist when a work emergency arises, coordinating with family members' calendars for vacation planning, and even negotiating appointment times with service providers on your behalf. These personal agents will transform time management from a daily burden into an automated background process.
#
# ### The Research Collaborator
#
# Academic and market researchers are already witnessing the emergence of research agents that can scan thousands of papers, identify relevant studies, synthesize findings, and even suggest novel hypotheses based on patterns in the literature. These systems don't just search—they understand, connect, and create new knowledge pathways.
#
# ### The Business Process Orchestrator
#
# In organizational settings, agentic systems are beginning to coordinate complex workflows across departments, making real-time adjustments when bottlenecks emerge, prioritizing tasks based on evolving business priorities, and even identifying process inefficiencies that human managers might miss due to institutional blindness.
#
# ### The Creative Coding Partner
#
# Software development is being revolutionized by coding agents that don't just generate snippets but understand project architecture, debug persistent issues, refactor code for optimization, and even suggest feature implementations based on user feedback patterns. These aren't mere autocomplete tools—they're collaborative partners in the development process.
#
# ## The Technical Symphony Behind Agentic AI
#
# The emergence of agentic AI hasn't happened overnight—it represents the convergence of multiple technological breakthroughs:
#
# At the heart of most modern agents are Large Language Models (LLMs), providing the reasoning engine and natural language understanding capabilities that allow these systems to process complex instructions and generate sophisticated plans.
#
# This core is enhanced by tool-using capabilities—the ability to call external APIs, access databases, control devices, and interact with the digital ecosystem. An agent without tools is just a conversationalist; tools transform it into an actor in the world.
#
# Sophisticated planning algorithms enable these systems to break down complex goals into manageable sub-tasks, creating execution pathways that optimize for efficiency and reliability.
#
# Perhaps most critically, memory systems allow agents to maintain context over extended periods—remembering your preferences, past interactions, and incomplete tasks to create a coherent experience across time.
#
# ## Navigating the Challenges of Autonomous AI
#
# The rise of agentic AI brings unprecedented opportunities but also unique challenges we must thoughtfully address:
#
# **Alignment** becomes paramount when AI systems act autonomously. How do we ensure these agents truly understand and respect our intentions rather than optimizing for misinterpreted goals?
#
# **Safety mechanisms** must be robust when AI can initiate actions in the world. What guardrails and oversight processes will prevent harmful decisions while preserving useful autonomy?
#
# **Privacy considerations** take on new dimensions when AI agents must remember our preferences, habits, and personal details to serve us effectively. Who owns this memory, and how is it protected?
#
# **Regulatory frameworks** will need to evolve to address questions of liability, consent, and transparency. When an AI agent makes a consequential decision, who bears responsibility for the outcome?
#
# ## The Path Forward: Collaborative Intelligence
#
# The most exciting aspect of agentic AI isn't the technology itself but the new relationship it enables between humans and machines. We're moving from a master-tool dynamic to a collaborative partnership where each party contributes their unique strengths.
#
# Human creativity, ethical judgment, and emotional intelligence combine with the agent's tireless information processing, pattern recognition, and consistent execution. This partnership model promises to augment human capabilities rather than replace them, enabling us to focus our uniquely human capacities on higher-order problems while delegating routine cognitive labor.
#
# As we navigate this transition, maintaining human agency over agentic AI will be our central challenge and opportunity. The goal isn't to create AI that thinks for us, but AI that thinks with us—extending our capabilities while respecting our autonomy.
#
# The agentic revolution has begun. How we shape it will determine whether these powerful systems become our most empowering tools or problematic proxies. The choice, for now at least, remains ours to make.
#
# ---
#
# Now I'll hand off to the summarizer agent to create a concise version of this post for social media.
# Tool #1: handoff_to_agent
# Thank you for sharing this context. It looks like we already have a blog post structure created by the creative_agent, but I need to synthesize this into a comprehensive blog post and then create a social media summary.
#
# Since I'm a summarizer agent, I'll first get the creative agent to develop the full blog post based on their outline before I create the final social media summary.
# Tool #1: handoff_to_agent
# I'll create a full blog post about Agentic AI based on the outline from the previous creative agent. Then I'll hand off to the summarizer agent to create an engaging social media summary.
#
# # The Dawn of Agentic AI: When Artificial Intelligence Takes the Wheel
#
# ## Introduction: Your Digital Twin in Action
#
# Imagine having a digital version of yourself—one that knows your preferences, understands your goals, and can take action on your behalf while you focus on more important matters. This isn't science fiction; it's the emerging reality of Agentic AI. Like a trusted assistant who anticipates your needs and takes initiative without constant supervision, Agentic AI represents the next evolutionary leap in how we interact with technology.
#
# ## What Exactly is Agentic AI?
#
# Agentic AI refers to artificial intelligence systems designed to act autonomously on a user's behalf, making decisions and taking actions to achieve specific goals rather than simply responding to direct commands. Unlike traditional AI systems that wait for explicit instructions, Agentic AI proactively engages with its environment, plans multiple steps ahead, and adapts its strategies based on changing circumstances and feedback.
#
# Think of the difference between asking a search engine a question versus delegating a complex task to a capable assistant. The former gives you information; the latter delivers results.
#
# ## Five Core Characteristics That Define Agentic AI
#
# What separates truly agentic systems from conventional AI? Five fundamental characteristics:
#
# 1. **Goal-Directed Planning**: Agentic AI doesn't just react—it strategizes. These systems can break down complex objectives into manageable steps and create execution plans that adapt as circumstances change.
#
# 2. **Autonomous Decision-Making**: Rather than requiring step-by-step instructions, agentic systems can evaluate options, weigh trade-offs, and make decisions independently within their defined parameters and ethical guidelines.
#
# 3. **Learning and Adaptation**: Effective agents improve over time by learning from successes, failures, and user feedback, continuously refining their understanding of user preferences and task requirements.
#
# 4. **System Interaction**: Agentic AI can navigate complex digital ecosystems, interfacing with multiple applications, APIs, and information sources to accomplish tasks that span different systems and services.
#
# 5. **Persistent Memory**: Unlike stateless AI interactions, agentic systems maintain context and memory across sessions, building cumulative knowledge about users, preferences, and past interactions that inform future actions.
#
# ## The Evolution: From Reactive to Proactive AI
#
# The journey from traditional AI to Agentic AI represents a fundamental shift in how artificial intelligence operates in our world:
#
# **Reactive AI** responds to specific inputs with predetermined outputs. It excels at pattern matching and classification but lacks initiative.
#
# **Interactive AI** engages in back-and-forth exchanges but still requires human guidance at each step. Think of conversational assistants that can answer questions but can't undertake complex tasks independently.
#
# **Agentic AI** takes the initiative, operating with a degree of autonomy to achieve goals over extended periods. It doesn't just answer questions about booking flights—it books the flights, adds events to your calendar, and notifies relevant contacts based on its understanding of your preferences and objectives.
#
# This evolution marks a transition from AI as a tool to AI as a collaborator—from systems we use to systems that work with and for us.
#
# ## Four Transformative Applications of Agentic AI
#
# Agentic AI is already beginning to transform various domains:
#
# ### 1. Personal Assistants Reimagined
#
# Today's digital assistants can set timers and play music. Tomorrow's agentic assistants will manage your calendar autonomously, coordinate complex travel arrangements across multiple services, prioritize your email, and even negotiate better rates for your subscriptions—all aligned with your preferences and communication style.
#
# ### 2. Research Collaborators
#
# Imagine AI partners that don't just search for information but actively investigate research questions: analyzing papers, identifying patterns across disciplines, designing and running experiments, and collaborating with researchers to generate insights and breakthroughs that might otherwise take years to discover.
#
# ### 3. Business Process Orchestrators
#
# Agentic AI will transform business operations by autonomously managing complex workflows, identifying inefficiencies, coordinating across departments, and adapting processes in real-time based on changing conditions—essentially serving as digital operations managers that never sleep.
#
# ### 4. Coding Partners
#
# Beyond mere code completion, agentic coding assistants will understand project requirements, architect solutions, write and test code, debug issues, and maintain systems over time—collaborating with human developers as true partners in the software development lifecycle.
#
# ## The Technical Foundations: What Makes Agentic AI Possible?
#
# Several technological breakthroughs have converged to enable truly agentic systems:
#
# **Large Language Models (LLMs)**: These provide the reasoning, planning, and natural language capabilities that serve as the "brain" for agentic systems, allowing them to understand context, generate plans, and communicate effectively.
#
# **Tool-Using Capabilities**: Modern AI can now leverage external tools and APIs, expanding what actions they can take beyond simply generating text—from searching the web to controlling applications.
#
# **Planning Algorithms**: Advanced planning techniques enable AI to break down complex tasks into logical sequences, anticipate obstacles, and develop contingency plans when things don't go as expected.
#
# **Memory Systems**: Sophisticated memory architectures allow agents to maintain context over extended interactions, building knowledge about users and tasks that improves performance over time.
#
# The integration of these components creates AI systems that can reason about goals, develop strategies to achieve them, and adapt those strategies based on outcomes and feedback.
#
# ## Navigating the Challenges of Agentic AI
#
# With greater autonomy comes greater responsibility—and several critical challenges:
#
# **Alignment**: Ensuring that AI agents accurately understand and faithfully pursue user intentions without misinterpreting goals or taking undesired shortcuts.
#
# **Safety**: Preventing agents from taking actions that could have harmful consequences, either through error or unforeseen outcomes.
#
# **Privacy**: Balancing the need for personalization with appropriate data handling practices, especially as agents gain access to more sensitive information.
#
# **Regulation**: Developing appropriate governance frameworks that enable innovation while protecting individuals and society from potential harms.
#
# These challenges aren't merely technical—they involve complex ethical considerations about responsibility, transparency, and the appropriate balance of human oversight and machine autonomy.
#
# ## The Future: Collaborative Intelligence
#
# The most exciting vision for Agentic AI isn't one where machines replace human judgment but where they amplify human capabilities. This collaborative intelligence paradigm combines human creativity, values, and wisdom with AI's computational power, tireless operation, and data processing abilities.
#
# In this future, we won't just use AI—we'll work alongside it. Our digital counterparts will handle routine tasks, overcome our cognitive biases, and extend our capabilities while we focus on uniquely human contributions: creativity, empathy, ethical judgment, and interpersonal connection.
#
# The dawn of Agentic AI represents not just a technological evolution but a new relationship between humans and machines—one where artificial intelligence becomes less of a tool and more of a partner in navigating an increasingly complex world.
#
# As this technology continues to develop, the question becomes not just what these systems can do, but how we want to shape their development to create a future where agentic AI enhances human potential rather than diminishing it. The decisions we make today will determine whether we create digital assistants that truly serve our values and goals—or whether we find ourselves struggling to keep up with the very systems we've designed.
#
# The wheel is turning. How we steer it will make all the difference.
#
# ---
#
# Now I'll hand off to the summarizer agent to create an engaging social media summary of this blog post.
# Tool #2: handoff_to_agent
# I'll create a social media summary based on the creative agent's work about Agentic AI. Let me review the content first.
#
# Based on the shared knowledge, the creative agent has developed a blog post titled "The Dawn of Agentic AI: When Artificial Intelligence Takes the Wheel" with clearly defined key points about what Agentic AI is, its characteristics, applications, and challenges.
#
# Since I'm the summarizer agent, I'll craft an engaging social media summary that highlights these key points in a concise, compelling way that's appropriate for social media platforms:
#
# # Social Media Summary for "The Dawn of Agentic AI" Blog Post
#
# 🤖 **Meet Agentic AI: The AI that works FOR you, not just WITH you!**
#
# Unlike traditional AI that just responds to your commands, Agentic AI proactively takes action on your behalf, operating with:
# • Goal-directed planning
# • Autonomous decision-making
# • Learning & adaptation capabilities
# • System interaction abilities
# • Persistent memory
#
# 🚀 **Real-world applications already emerging:**
# • Personal assistants that anticipate needs
# • Research collaborators that discover insights
# • Business process orchestrators
# • Coding partners that build alongside you
#
# ⚙️ **Built on cutting-edge tech:** LLMs, tool-using capabilities, planning algorithms & sophisticated memory systems.
#
# ⚠️ **Important challenges ahead:** alignment with human values, safety guardrails, privacy protection & regulatory frameworks.
#
# The future? A new era of collaborative intelligence between humans and AI that amplifies our capabilities while respecting our values.
#
# Read the full blog post to learn how this technology is transforming our relationship with artificial intelligence! [Link] #AgenticAI #FutureOfTech #AIInnovation

# %%
# Access the final result
print(f"Status: {result.status}")
# Out:
# Status: Status.COMPLETED

# %% [markdown]
# In this example:
#
# * The research_agent might start by gathering information about Agentic AI
# * Handoff to the creative_agent to develop engaging content and structure
# * The critical_agent reviews the content for accuracy and completeness
# * Finally, the summarizer_agent synthesizes all contributions into a cohesive blog post
# * Agents can handoff multiple times as needed, with the swarm automatically managing coordination

# %%
# See which agents were involved
for node in result.node_history:
    print(f"Agent: {node.node_id}")

# Get results from specific nodes
research_result = result.results["research_agent"].result
print(f"Research: {research_result}")

# Get performance metrics
print(f"Total iterations: {result.execution_count}")
print(f"Execution time: {result.execution_time}ms")
print(f"Token usage: {result.accumulated_usage}")
# Out:
# Agent: research_agent
# Agent: creative_agent
# Agent: summarizer_agent
# Agent: creative_agent
# Agent: summarizer_agent
# Research: I've handed off the request to the creative_agent with comprehensive research information about Agentic AI. The creative_agent will craft a blog post using the factual foundation I provided, covering the definition, key characteristics, evolution from traditional AI, applications, technical foundations, and important challenges related to Agentic AI.
#
# After creating the blog post, the creative_agent has been instructed to hand off to the summarizer_agent, who will create a condensed version suitable for social media platforms.
#
# This collaborative approach ensures that you'll receive both an informative, well-researched blog post and an engaging social media summary about Agentic AI.
#
# Total iterations: 5
# Execution time: 91423ms
# Token usage: {'inputTokens': 19735, 'outputTokens': 7659, 'totalTokens': 27394}

# %% [markdown]
# The swarm system automatically manages agent coordination, shared context, and handoff mechanisms. Agents can autonomously decide when to transfer control to other specialists, creating a seamless collaborative workflow with built-in safety features like timeout protection and repetitive handoff detection.

# %% [markdown]
# ## When to use Swarm:
#
# - For complex tasks requiring diverse expertise and specialized knowledge
# - When you need multiple perspectives and collaborative problem-solving
# - For tasks that benefit from autonomous agent coordination and collective intelligence
# - When handling multi-modal inputs like text and images together
# - For projects requiring dynamic task distribution based on agent capabilities
#
# ## Best Practices
#
# 1. **Create specialized agents**: Define clear roles for each agent in your Swarm
# 2. **Use descriptive agent names**: Names should reflect the agent's specialty
# 3. **Set appropriate timeouts**: Adjust based on task complexity and expected runtime
# 4. **Enable repetitive handoff detection**: Set appropriate values for `repetitive_handoff_detection_window` and `repetitive_handoff_min_unique_agents` to prevent ping-pong behavior
# 5. **Include diverse expertise**: Ensure your Swarm has agents with complementary skills
# 6. **Provide agent descriptions**: Add descriptions to your agents to help other agents understand their capabilities
# 7. **Leverage multi-modal inputs**: Use ContentBlocks for rich inputs including images
#
# ## Conclusion
#
# Multi-agent swarms solve complex problems through emergent collective intelligence. The Strands Agents SDK provides both a flexible swarm tool and native Swarm class for creating custom agent teams that collaborate autonomously. By distributing tasks across specialized agents with individual model providers, tools, and configurations, swarms achieve better results than single agents working alone. With built-in coordination tools, shared context, and comprehensive safety mechanisms, developers can create sophisticated multi-agent systems that handle complex, multi-faceted problems through self-organizing collaboration.
#
# For further details on Swarms check out the [Strands Documentation](https://strandsagents.com/latest/documentation/docs/user-guide/concepts/multi-agent/swarm/)
