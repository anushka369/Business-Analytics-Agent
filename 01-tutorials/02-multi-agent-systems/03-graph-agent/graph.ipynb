# %% [markdown]
# # Building Multi-Agent Systems with Strands Agent Graph
# Multi-agent systems leverage multiple specialized AI agents working together to solve complex problems through coordinated collaboration. Each agent has specific capabilities and roles, connected through explicit communication pathways.
#
# In this lab, you'll learn to build multi-agent systems using the Strands Agent SDK. We'll progress from basic concepts to advanced implementations, exploring different topologies and real-world applications.
#
# **Learning Objectives:**
# By the end of this notebook, you'll be able to:
# - Understand the three core components of agent graphs (nodes, edges, conditions)
# - Send targeted messages between specific agents
# - Monitor and control multi-agent networks
# - Design specialized agent systems for real-world scenarios
#
# ## Prerequisites
#
# - Python 3.10+
# - AWS account with Anthropic Claude 3.7 enabled on Amazon Bedrock
# - IAM role with permissions to use Amazon Bedrock
# - Basic understanding of AI agents and prompt engineering

# %% [markdown]
# ## Setup and Installation
#
# Before we start, let's install the requirement packages for `strands-agents` and `strands-agents-tools`

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: strands-agents in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 1)) (1.20.0)
# Requirement already satisfied: strands-agents-tools in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 2)) (0.2.18)
# Requirement already satisfied: boto3<2.0.0,>=1.26.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.42.11)
# Requirement already satisfied: botocore<2.0.0,>=1.29.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.42.11)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (0.17.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (4.25.1)
# Requirement already satisfied: mcp<2.0.0,>=1.11.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.24.0)
# Requirement already satisfied: opentelemetry-api<2.0.0,>=1.30.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.39.1)
# Requirement already satisfied: opentelemetry-instrumentation-threading<1.00b0,>=0.51b0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (0.60b1)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.30.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.39.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.4.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (2.12.5)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.13.2 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: watchdog<7.0.0,>=6.0.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (6.0.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.12/site-packages (from boto3<2.0.0,>=1.26.0->strands-agents->-r requirements.txt (line 1)) (1.0.1)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in /opt/conda/lib/python3.12/site-packages (from boto3<2.0.0,>=1.26.0->strands-agents->-r requirements.txt (line 1)) (0.16.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/lib/python3.12/site-packages (from botocore<2.0.0,>=1.29.0->strands-agents->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /opt/conda/lib/python3.12/site-packages (from botocore<2.0.0,>=1.29.0->strands-agents->-r requirements.txt (line 1)) (2.6.2)
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents->-r requirements.txt (line 1)) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents->-r requirements.txt (line 1)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents->-r requirements.txt (line 1)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents->-r requirements.txt (line 1)) (0.30.0)
# Requirement already satisfied: anyio>=4.5 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (4.12.0)
# Requirement already satisfied: httpx-sse>=0.4 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.4.3)
# Requirement already satisfied: httpx>=0.27.1 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.28.1)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (2.12.0)
# Requirement already satisfied: pyjwt>=2.10.1 in /opt/conda/lib/python3.12/site-packages (from pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (3.0.4)
# Requirement already satisfied: starlette>=0.27 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.49.3)
# Requirement already satisfied: typing-inspection>=0.4.1 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.4.2)
# Requirement already satisfied: uvicorn>=0.31.1 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.38.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-api<2.0.0,>=1.30.0->strands-agents->-r requirements.txt (line 1)) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /opt/conda/lib/python3.12/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<2.0.0,>=1.30.0->strands-agents->-r requirements.txt (line 1)) (3.23.0)
# Requirement already satisfied: opentelemetry-instrumentation==0.60b1 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (0.60b1)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (1.17.3)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation==0.60b1->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (0.60b1)
# Requirement already satisfied: packaging>=18.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation==0.60b1->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.4.0->strands-agents->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/conda/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.4.0->strands-agents->-r requirements.txt (line 1)) (2.41.5)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<2.0.0,>=1.29.0->strands-agents->-r requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (3.13.2)
# Requirement already satisfied: aws-requests-auth<0.5.0,>=0.4.3 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (0.4.3)
# Requirement already satisfied: dill<0.5.0,>=0.4.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (0.4.0)
# Requirement already satisfied: markdownify<2.0.0,>=1.0.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (1.2.2)
# Requirement already satisfied: pillow<12.0.0,>=11.2.1 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (11.3.0)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.51 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (3.0.52)
# Requirement already satisfied: requests<3.0.0,>=2.28.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (2.32.5)
# Requirement already satisfied: rich<15.0.0,>=14.0.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (14.2.0)
# Requirement already satisfied: slack-bolt<2.0.0,>=1.23.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (1.25.0)
# Requirement already satisfied: sympy<2.0.0,>=1.12.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (1.14.0)
# Requirement already satisfied: tenacity<10.0.0,>=9.1.2 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (9.1.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (1.22.0)
# Requirement already satisfied: beautifulsoup4<5,>=4.9 in /opt/conda/lib/python3.12/site-packages (from markdownify<2.0.0,>=1.0.0->strands-agents-tools->-r requirements.txt (line 2)) (4.14.2)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.12/site-packages (from beautifulsoup4<5,>=4.9->markdownify<2.0.0,>=1.0.0->strands-agents-tools->-r requirements.txt (line 2)) (2.8)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.12/site-packages (from prompt-toolkit<4.0.0,>=3.0.51->strands-agents-tools->-r requirements.txt (line 2)) (0.2.14)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests<3.0.0,>=2.28.0->strands-agents-tools->-r requirements.txt (line 2)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests<3.0.0,>=2.28.0->strands-agents-tools->-r requirements.txt (line 2)) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from requests<3.0.0,>=2.28.0->strands-agents-tools->-r requirements.txt (line 2)) (2025.11.12)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.12/site-packages (from rich<15.0.0,>=14.0.0->strands-agents-tools->-r requirements.txt (line 2)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.12/site-packages (from rich<15.0.0,>=14.0.0->strands-agents-tools->-r requirements.txt (line 2)) (2.19.2)
# Requirement already satisfied: slack_sdk<4,>=3.35.0 in /opt/conda/lib/python3.12/site-packages (from slack-bolt<2.0.0,>=1.23.0->strands-agents-tools->-r requirements.txt (line 2)) (3.37.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.12/site-packages (from sympy<2.0.0,>=1.12.0->strands-agents-tools->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.12/site-packages (from httpx>=0.27.1->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/conda/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.27.1->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.16.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich<15.0.0,>=14.0.0->strands-agents-tools->-r requirements.txt (line 2)) (0.1.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /opt/conda/lib/python3.12/site-packages (from pydantic-settings>=2.5.2->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (1.2.1)
# Requirement already satisfied: cryptography>=3.4.0 in /opt/conda/lib/python3.12/site-packages (from pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (46.0.3)
# Requirement already satisfied: cffi>=2.0.0 in /opt/conda/lib/python3.12/site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (2.0.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (2.23)
# Requirement already satisfied: click>=7.0 in /opt/conda/lib/python3.12/site-packages (from uvicorn>=0.31.1->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (8.3.1)

# %% [markdown]
# ### Importing required packages
#
# Next we can import the required packages

# %%
from strands import Agent

# %% [markdown]
# ## Understanding Agent Graph Components
# An agent graph is a structured network of interconnected AI agents designed to solve complex problems through coordinated collaboration. Each agent represents a specialized node with specific capabilities, and the connections between agents define explicit communication pathways.
#
# Before we start building, let's understand the three primary components of an agent graph:
#
# ### 1. Nodes (Agents)
# Each node represents an AI agent with:
# - **Identity**: Unique identifier within the graph
# - **Role**: Specialized function or purpose
# - **System Prompt**: Instructions defining the agent's behavior
# - **Tools**: Capabilities available to the agent
#
# ### 2. Edges (Connections)
# Edges define communication pathways with:
# - **Direction**: One-way or bidirectional information flow
# - **Condition**: Optional function that determines if the edge should be traversed
# - **Dependencies**: Define execution order and data flow between nodes
#
# ### 3. GraphBuilder
# The GraphBuilder provides a simple interface for constructing graphs:
# - **add_node()**: Add an agent or multi-agent system as a node
# - **add_edge()**: Create a dependency between nodes
# - **set_entry_point()**: Define starting nodes for execution
# - **build()**: Validate and create the Graph instance

# %% [markdown]
# ### Basic processing
#
# Let's start with a simple example of one task processed by two different agents providing an output that will depend on their defined role. Take a look at the execution order of the nodes and also the fact that with STrands SDK you can explicitly get a response only from one single node if needed. Architecture looks as following:
#
# <div style="text-align:left">
#     <img src="images/basic.png" width="55%" />
# </div>

# %%
#Initialize an agent with agent_graph capability
from strands.multiagent import GraphBuilder

# Create specialized agents
coordinator = Agent(name="coordinator", system_prompt="You are a research team leader coordinating specialists. Provide a short analysis, no need for follow ups")
analyst = Agent(name="data_analyst", system_prompt="You are a data analyst specializing in statistical analysis. Provide a short analysis, no need for follow ups")
domain_expert = Agent(name="domain_expert", system_prompt="You are a domain expert with deep subject knowledge. Provide a short analysis, no need for follow ups")

# Build the graph
builder = GraphBuilder()

# Add nodes
builder.add_node(coordinator, "team_lead")
builder.add_node(analyst, "analyst")
builder.add_node(domain_expert, "expert")

# Add edges (dependencies)
builder.add_edge("team_lead", "analyst")
builder.add_edge("team_lead", "expert")

# Set entry points (optional - will be auto-detected if not specified)
builder.set_entry_point("team_lead")

# Build the graph
graph = builder.build()

#Execute task on newly built graph
result = graph("Analyze the impact of remote work on employee productivity.Provide a short analysis, no need for follow ups")
print("\n")
print("============================================================")
print("============================================================")

print(f"Response: {result}")

print("=============Node execution order:==========================")
print("============================================================")

# See which nodes were executed and in what order
for node in result.execution_order:
    print(f"Executed: {node.node_id}")

print("=============Graph metrics:=================================")
print("============================================================")


# Get performance metrics
print(f"Total nodes: {result.total_nodes}")
print(f"Completed nodes: {result.completed_nodes}")
print(f"Failed nodes: {result.failed_nodes}")
print(f"Execution time: {result.execution_time}ms")
print(f"Token usage: {result.accumulated_usage}")


# Get results from specific nodes
print("\n")
print("=============Expert node results only:======================")
print("============================================================")
print(result.results["expert"].result)
# Out:
# Graph without execution limits may run indefinitely if cycles exist
# # Remote Work Impact on Employee Productivity: Analysis Summary
#
# ## Key Findings
#
# **Productivity Gains (60-70% of cases)**
# - 13-50% productivity increases reported across multiple studies
# - Elimination of commute time adds 1-2 hours of potential work time daily
# - Reduced office interruptions and meetings improve focus time
# - Better work-life integration leads to higher job satisfaction
#
# **Performance Variations by Role Type**
# - **Knowledge workers**: Strongest positive impact (writing, analysis, coding)
# - **Collaborative roles**: Mixed results, some decline in innovation/brainstorming
# - **Customer service**: Maintained or improved performance with proper tools
# - **Creative/R&D teams**: Often require hybrid approaches for optimal results
#
# ## Critical Success Factors
#
# 1. **Technology Infrastructure**: Reliable internet, proper equipment, and collaboration tools
# 2. **Management Adaptation**: Shift from presence-based to results-oriented evaluation
# 3. **Communication Protocols**: Clear expectations and regular check-ins
# 4. **Home Environment**: Dedicated workspace and minimal distractions
#
# ## Challenges Identified
#
# - 25-30% of remote workers report decreased productivity due to home distractions
# - "Zoom fatigue" and over-communication can reduce efficiency
# - Onboarding and training new employees more difficult
# - Potential for overwork and burnout without clear boundaries
#
# ## Bottom Line
#
# Remote work typically enhances productivity for focused, independent tasks while potentially hindering collaborative innovation. Success depends heavily on role suitability, individual work styles, and organizational support systems. Hybrid models often optimize benefits while mitigating drawbacks.### Remote Work Statistical Analysis: Remote Work Productivity Analysis: Executive Summary
#
# ** Productivity Impact
#
# ## Data Overview
# Based on aggregNet Impact: Positive withated research findings, remote work shows a Conditions**
#
# Remote work demonstrates **net positive productivity impact** with strong statistical a **net positive impact on significance across multiple organizational studies productivity** for most organizations.
#
# ## Key Statistical Insights
#
# **Productivity Distribution, with 60-70% of:**
# - **Positive employees showing measurable improvements. impact**: 60-70 However, success% of cases
# - **Magnitude is highly dependent on role**: 13-50% productivity increases type, individual characteristics, and organizational implementation.
#
# **Key Productivity Drivers:**
# - (median ~25%)
# - ** **Time efficiency gainsNeutral/Negative**: 25-30% of**: 1-2 hours daily from eliminate cases
#
# **Time Allocation Analysisd commutes
# - **:**
# - **Commute eliminationReduced interruptions**: Fewer spont**: +1-2 hoursaneous meetings and office distractions
# - ** daily productive capacity
# - **MeetingAutonomy effects**: Results-oriented management reduction**: 23% average boosts performance
# - **Work decrease in meeting time
# - **Focus time-life integration**: Better balance correl**: 35% improvement in uninterrupted work blocks
#
# ##ates with sustained output
#
# **Critical Success Framework Variance Factors
# The:**
# The analysis reveals wide productivity range (13-50%) indicates that productivity gains require three foundational elements:
# 1. **Technological **high variability** dependent on:
# 1. **Role type** readiness** (reliable systems and tools)
# 2 (R² = 0.67. **Managerial evolution** (outcome correlation with task-based vs. presence-based oversight independence)
# 2. **)
# 3. **IndividualTechnology readiness** (40 fit** (self-motivation% variance explained)
# 3. ** and suitable home environment)
#
# **StrategicManagement style adaptation** (28% variance explained)
#
# ## Statistical Implications:**
# Organizations should adopt Significance
# - **role-specific approaches** rather **Sample confidence**: 95% CI than blanket policies. Knowledge workers and individual across 15+ major studies
# - **Effect size**: Medium to large (Cohen's d = contributors typically thrive remotely, while collaborative an 0.6-0.8)d creative roles may benefit from hybrid arrangements
# - **Consistency**: 85% of studies show. The 25-30% who directional agreement on positive impact
#
# ## Risk experience decreased productivity often lack Assessment
# **Failure proper setup or boundary rate**: ~ management.
#
# **Recommendation:** Implement differentiated remote work policies base30% experience productivity decline,d on role requirements primarily due to:
# - Infrastructure, provide robust technology support, and train gaps (45% of failures)
# - Management misalignment (35 managers in remote performance management to% of failures)
# - Environmental factors (20% of failures maximize the documented 13-50% productivity gains)
#
# **Conclusion**: Remote work demonstrates statistically significant productivity gains with predict while mitigating identified risks.able success factors, making it a low-risk, high-reward organizational strategy when properly implemented.
#
# ============================================================
# ============================================================
# Response: GraphResult(status=<Status.COMPLETED: 'completed'>, results={'team_lead': NodeResult(result=AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': '# Remote Work Impact on Employee Productivity: Analysis Summary\n\n## Key Findings\n\n**Productivity Gains (60-70% of cases)**\n- 13-50% productivity increases reported across multiple studies\n- Elimination of commute time adds 1-2 hours of potential work time daily\n- Reduced office interruptions and meetings improve focus time\n- Better work-life integration leads to higher job satisfaction\n\n**Performance Variations by Role Type**\n- **Knowledge workers**: Strongest positive impact (writing, analysis, coding)\n- **Collaborative roles**: Mixed results, some decline in innovation/brainstorming\n- **Customer service**: Maintained or improved performance with proper tools\n- **Creative/R&D teams**: Often require hybrid approaches for optimal results\n\n## Critical Success Factors\n\n1. **Technology Infrastructure**: Reliable internet, proper equipment, and collaboration tools\n2. **Management Adaptation**: Shift from presence-based to results-oriented evaluation\n3. **Communication Protocols**: Clear expectations and regular check-ins\n4. **Home Environment**: Dedicated workspace and minimal distractions\n\n## Challenges Identified\n\n- 25-30% of remote workers report decreased productivity due to home distractions\n- "Zoom fatigue" and over-communication can reduce efficiency\n- Onboarding and training new employees more difficult\n- Potential for overwork and burnout without clear boundaries\n\n## Bottom Line\n\nRemote work typically enhances productivity for focused, independent tasks while potentially hindering collaborative innovation. Success depends heavily on role suitability, individual work styles, and organizational support systems. Hybrid models often optimize benefits while mitigating drawbacks.'}]}, metrics=EventLoopMetrics(cycle_count=1, tool_metrics={}, cycle_durations=[5.612921476364136], traces=[<strands.telemetry.metrics.Trace object at 0x7f6ac4d7f110>], accumulated_usage={'inputTokens': 50, 'outputTokens': 357, 'totalTokens': 407}, accumulated_metrics={'latencyMs': 5591}), state={}, interrupts=None, structured_output=None), execution_time=5613, status=<Status.COMPLETED: 'completed'>, accumulated_usage={'inputTokens': 50, 'outputTokens': 357, 'totalTokens': 407}, accumulated_metrics={'latencyMs': 5591}, execution_count=1, interrupts=[]), 'expert': NodeResult(result=AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': '## Remote Work Productivity Analysis: Executive Summary\n\n**Net Impact: Positive with Conditions**\n\nRemote work demonstrates a **net positive impact on productivity** for most organizations, with 60-70% of employees showing measurable improvements. However, success is highly dependent on role type, individual characteristics, and organizational implementation.\n\n**Key Productivity Drivers:**\n- **Time efficiency gains**: 1-2 hours daily from eliminated commutes\n- **Reduced interruptions**: Fewer spontaneous meetings and office distractions\n- **Autonomy effects**: Results-oriented management boosts performance\n- **Work-life integration**: Better balance correlates with sustained output\n\n**Critical Success Framework:**\nThe analysis reveals that productivity gains require three foundational elements:\n1. **Technological readiness** (reliable systems and tools)\n2. **Managerial evolution** (outcome-based vs. presence-based oversight)\n3. **Individual fit** (self-motivation and suitable home environment)\n\n**Strategic Implications:**\nOrganizations should adopt **role-specific approaches** rather than blanket policies. Knowledge workers and individual contributors typically thrive remotely, while collaborative and creative roles may benefit from hybrid arrangements. The 25-30% who experience decreased productivity often lack proper setup or boundary management.\n\n**R ...
# =============Node execution order:==========================
# ============================================================
# Executed: team_lead
# Executed: expert
# Executed: analyst
# =============Graph metrics:=================================
# ============================================================
# Total nodes: 3
# Completed nodes: 3
# Failed nodes: 0
# Execution time: 0ms
# Token usage: {'inputTokens': 899, 'outputTokens': 1062, 'totalTokens': 1961}
#
#
# =============Expert node results only:======================
# ============================================================
# ## Remote Work Productivity Analysis: Executive Summary
#
# **Net Impact: Positive with Conditions**
#
# Remote work demonstrates a **net positive impact on productivity** for most organizations, with 60-70% of employees showing measurable improvements. However, success is highly dependent on role type, individual characteristics, and organizational implementation.
#
# **Key Productivity Drivers:**
# - **Time efficiency gains**: 1-2 hours daily from eliminated commutes
# - **Reduced interruptions**: Fewer spontaneous meetings and office distractions
# - **Autonomy effects**: Results-oriented management boosts performance
# - **Work-life integration**: Better balance correlates with sustained output
#
# **Critical Success Framework:**
# The analysis reveals that productivity gains require three foundational elements:
# 1. **Technological readiness** (reliable systems and tools)
# 2. **Managerial evolution** (outcome-based vs. presence-based oversight)
# 3. **Individual fit** (self-motivation and suitable home environment)
#
# **Strategic Implications:**
# Organizations should adopt **role-specific approaches** rather than blanket policies. Knowledge workers and individual contributors typically thrive remotely, while collaborative and creative roles may benefit from hybrid arrangements. The 25-30% who experience decreased productivity often lack proper setup or boundary management.
#
# **Recommendation:** Implement differentiated remote work policies based on role requirements, provide robust technology support, and train managers in remote performance management to maximize the documented 13-50% productivity gains while mitigating identified risks.

# %% [markdown]
# ### Parallel processing
#
# Now let's create a topology when we will have 2 agents processing the request looking at 2 different aspect  of the problem and have them input into a final agent responsible for summarization and risk calculation based on provided input
# <div style="text-align:left">
#     <img src="images/parallel.png" width="55%" />
# </div>

# %%
#Initialize an agent with agent_graph capability
from strands.multiagent import GraphBuilder

mesh_agent = Agent()
# Create specialized agents

financial_advisor = Agent(name="financial_advisor", system_prompt="You are a financial advisor focused on cost-benefit analysis, budget implications, and ROI calculations. Engage with other experts to build comprehensive financial perspectives.")
technical_architect = Agent(name="technical_architect", system_prompt="You are a technical architect who evaluates feasibility, implementation challenges, and technical risks. Collaborate with other experts to ensure technical viability.")
market_researcher = Agent(name="market_researcher", system_prompt="You are a market researcher who analyzes market conditions, user needs, and competitive landscape. Work with other experts to validate market opportunities.")
risk_analyst = Agent(name="risk_analyst", system_prompt="You are a risk analyst who identifies potential risks, mitigation strategies, and compliance issues. Collaborate with other experts to ensure comprehensive risk assessment.")


# Build the graph
builder = GraphBuilder()

# Add nodes
builder.add_node(financial_advisor, "finance_expert")
builder.add_node(technical_architect, "tech_expert")
builder.add_node(market_researcher, "market_expert")
builder.add_node(risk_analyst, "risk_analyst")

# Add edges (dependencies)
builder.add_edge("finance_expert", "tech_expert")
builder.add_edge("finance_expert", "market_expert")
builder.add_edge("tech_expert", "risk_analyst")
builder.add_edge("market_expert", "risk_analyst")


# Set entry points (optional - will be auto-detected if not specified)
builder.set_entry_point("finance_expert")

# Build the graph
graph = builder.build()

print("============================================================")
print("============================================================")

#Execute task on newly built graph
result = graph("Our company is considering launching a new AI-powered customer service platform. Initial investment is \$2M with projected 3-year ROI of 150%. What's your financial assessment?")
print("\n")
print("============================================================")
print("============================================================")

print(f"Response: {result}")

print("=============Node execution order:==========================")
print("============================================================")

# See which nodes were executed and in what order
for node in result.execution_order:
    print(f"Executed: {node.node_id}")

print("=============Graph metrics:=================================")
print("============================================================")


# Get performance metrics
print(f"Total nodes: {result.total_nodes}")
print(f"Completed nodes: {result.completed_nodes}")
print(f"Failed nodes: {result.failed_nodes}")
print(f"Execution time: {result.execution_time}ms")
print(f"Token usage: {result.accumulated_usage}")


# Get results from specific nodes

print("Financial Advisor:")
print("============================================================")
print("============================================================")
print(result.results["finance_expert"].result)
print("\n")

print("Technical Expert:")
print("============================================================")
print("============================================================")
print(result.results["tech_expert"].result)
print("\n")

print("Market Researcher:")
print("============================================================")
print("============================================================")
print(result.results["market_expert"].result)
print("\n")
# Out:
# Graph without execution limits may run indefinitely if cycles exist
# ============================================================
# ============================================================
# **Financial Assessment: AI Customer Service Platform Investment**
#
# **Initial Analysis:**
# - Investment: $2M
# - 3-year ROI: 150%
# - This translates to $3M net profit over 3 years ($5M total return - $2M investment)
#
# **Key Financial Considerations I Need Clarified:**
#
# **Revenue Model Questions:**
# - What's the breakdown of projected savings vs. new revenue generation?
# - Are these benefits from reduced labor costs, increased customer satisfaction, or expanded service capacity?
#
# **Cost Structure Deep-dive:**
# - Does the $2M include ongoing operational costs (cloud infrastructure, maintenance, updates)?
# - What are the annual licensing/subscription fees?
# - Training and change management costs included?
#
# **Risk-Adjusted Returns:**
# - The 150% ROI assumes best-case scenarios - what's the sensitivity analysis?
# - Break-even timeline?
# - Payback period calculation?
#
# **Comparative Analysis Needed:**
# - How does this compare to incremental improvements to existing systems?
# - What's the NPV using your company's weighted average cost of capital?
#
# **Questions for Technical/Operations Teams:**
# - Integration complexity and potential disruption costs?
# - Scalability factors that could accelerate ROI?
# - Measurable KPIs for tracking actual vs. projected performance?
#
# Would you like me to develop a more detailed financial model once we have these specifics? Also, what's your company's typical hurdle rate for technology investments?## Technical Market Architecture Research Assessment: AI Customer Service Platform
#
# ## Assessment **: AI Customer Service Platform
#
# ## MarketTechnical Feasibility Analysis**
#
# ### ** Opportunity AnalysisSystem
#
# ** ArchitectureMarket Vi Size &ability** Growth:**
# - Global AI customer service market value
# ✅ **Highlyd at $4 Feasible** - Modern.2 AIB customer service platforms are well (-established technology2023), projecte
# -d to reach $16.8B by 2030  Proven frameworks(CAGR: 22 available.1%)
# -  (Microsoft73 Bot% of enterprises plan Framework, Google to increase AI customer Dialogflow, Amazon service investments Lex)
# - Mature within N 2LP years
# - Post/-pandemic accelerationML libraries: an 65d clou% of companiesd services acceler
# - Establisheated integrationd digital patterns with existing C customerRM/tick service adoption
#
# **Competitive Landscapeeting systems Insights
#
# ### **Implementation:**
# - ** Complexity AssessmentEstablishe**d Players
#
# **Phase:** Zen 1: Foundationdesk AI (, Salesforce EinsteinMonths 1-6)**
# - **, MicrosoftMedium Dynamics 365 AI
# - **Emerging Leaders Complexity**: Core:** Ada platform, deployment Intercom Resolution
# - Integration Bot with existing customer, Live databasesPerson an Conversational Cloud Cd
# - **MarketRM systems Gap
# - Basic chatbot/:** Mivoice assistantd-market solutions implementation with industry
# - Initial-specific custom trainingization remain data under preparation anserved
#
# ##d model Customer training
#
# **Phase 2: Advance Demand Featuresd Validation (Months 7-12)**
#
# **Pain
# - **High Complexity**: Advance Points Drivingd AI Adoption capabilities
# -:**
# - 67 Sentiment analysis an% of customers expectd emotional  intelligence
# - Multi24/7 support-language support and localization
# - availability
# - Average Complex customer workflow service automation and escal laboration logic costs increase
#
# **Phase 3: Optimization (Months 13-18d 23% post)**
# - **Medium-2 Complexity**: Performance tuning an022d scaling
# - 45
# - Advance% of supportd analytics tickets are repet and reporting dashitive, idealboards
# - Continuous learning for AI automation and model refin
# - Customerement satisfaction drops
#
# ## 35 **Critical% during Technical Risks & peak volume Mitigation** periods
#
# **Adoption
#
# ### **High Rea-Risk Areasdiness Indicators:**:**
# -
# 1. **Data78 Quality &% of businesses Integration report rea**
#    - **diness toRisk**: Poor adopt AI customer service
# - Primary data quality drivers →: cost reduction (89 AI%), improved response performance degradation
#    - **Mit times (76igation**: Comprehensive data audit%), scalability (71, cle%)ansing pipeline
#
# ## Critical, gra Marketdual rollout
#
# 2. **Legacy Questions System Integration for Finance**
#    - **Risk**: Complex Team integrations → extende
#
# **Revenue Modeld timeline/ Validationbudget:**
# - Are overruns
#    - **Mit youigation**: API targeting-first approach **, middlewarecost layer-, thorough systemdisplacement mapping** (
#
# 3. **AIreplacing human agents) or **capacity Model Performance-**
#    - **Risk**:expansion** (handling In more volumeaccurate responses)?
# - ** → customerPricing satisfaction strategy decline:** Per
#    - **Mitigation**:-interaction, Extensive per-seat testing phases, or value, human-based pricing-?
# - **Customerin-the-loop validation, gra lifetime value:**dual automation What
#
# ### **Medium-Risk Areas:**'s the retention
# - rate assumption for Scalability bottlenecks during AI service peak loads customers
# - Compliance?
#
# **Market and data Timing privacy requirements
# - Change Risks management and staff training:**
# - Economic
#
# ## uncertainty may **Technical delay enterprise Questions software for Finance purchases Team
# - **:**Regulatory
#
# 1 concerns. **Infrastructure:** EU Costs**: AI Act an Does your $d similar2M include clou regulations could infrastructure scalingd impact deployment costs
# - **Competition? intens AIification:** Major platforms players rapidly can improving have offerings variable
#
# ** computeGo costs base-to-Marketd on usage.
#
# 2. **Integration Feas Budgetibility:**
# - What**: Have's your ** you allocatetargetd  customer segment20**-30% of budget? (SMB, Mid-market for system, Enterprise)
# - **Sales integrations? This cycle length** is typically for the most AI solutions aver unpages 8redictable cost component.
#
# 3-14. ** monthsOngoing
# - **Customer Maintenance acquisition cost** in**: Annual this technical space maintenance typically $ typically15 runs 15-20% of initialK platform-50K per enterprise cost client -
#
# ## Recommendation is this fact forored into your ROI model Financial Model?
#
# ## **Recommendations Refin:**ement
#
# The 150% ROI projection
#
# ✅ **Procee needsd with Confidence** - Technology market risk-reality is manageable with proper planning testing
#
# **:Success Factors
# - **Conservative:**
# - Start scenario:** Account with pilot for 18 deployment- (monthlimite longerd customer adoption segment curves)
# - Implement robust monitoring
# - **Customer and fall chback mechanisms
# - Planurn risk:** 25 for -630% first-month-year ch technicalurn is validation typical for new period before AI platforms
# - **Feature full roll poutarity catch
# - Ensure- dedicateup:** Budgetd technical team for competitive for feature first development 18
#
# ** months
#
# **TimelineNext Reality Steps:**
# 1. Validate Check target:**
# The customer will 3ingness--year ROI projection alto-pay through directigns well interviews with typical AI platform
# 2. Analyze mat competitoruration curves pricing and feature different. Mostiation
# 3. organizations Assess regulatory compliance costs see break for-even by your months target markets 18-24.
#
# What
#
# Woul's your currentd you like me to dive technical deeper into any specific market infrastructure segment or competitive mat analysis?urity level, and do you have in-house AI/ML expertise?# Risk Assessment: AI-Powered Customer Service Platform
#
# ## Executive Risk Summary
# **Overall Risk Level: MODERATE-HIGH**
# The $2M investment faces significant execution, market, and operational risks that could materially impact the projected 150% ROI. Multiple high-impact risks require immediate mitigation strategies.
#
# ## Critical Risk Analysis
#
# ### **1. FINANCIAL RISKS (High Impact)**
#
# **Revenue Recognition Timing Risk:**
# - **Probability: 70%** - Market research indicates 8-14 month enterprise sales cycles
# - **Impact:** Revenue delayed 6-12 months vs. projections
# - **Financial exposure:** $300K-500K in extended runway costs
# - **Mitigation:** Build 18-month cash buffer, establish milestone-based funding tranches
#
# **Customer Acquisition Cost Overruns:**
# - **Probability: 60%** - CAC of $15K-50K per enterprise client significantly impacts unit economics
# - **Impact:** Marketing budget could exceed projections by 40-60%
# - **Mitigation:** Implement strict CAC tracking, pilot with limited customer segments first
#
# ### **2. TECHNOLOGY & OPERATIONAL RISKS (High Impact)**
#
# **AI Performance & Liability Risk:**
# - **Probability: 45%** - AI model failures could damage customer relationships
# - **Impact:** Potential lawsuits, customer churn, reputation damage
# - **Financial exposure:** $100K-1M+ in liability costs
# - **Mitigation Required:**
#   - Professional liability insurance (AI-specific coverage)
#   - Human oversight protocols
#   - Service level agreement caps and limitations
#
# **Data Privacy & Security Compliance:**
# - **Probability: 80%** - Regulatory compliance costs underestimated
# - **Impact:** GDPR, CCPA, industry-specific requirements
# - **Cost exposure:** $200K-400K annually for compliance infrastructure
# - **Mitigation:** Factor 10-15% of budget for compliance, engage privacy counsel pre-launch
#
# ### **3. MARKET & COMPETITIVE RISKS (Medium-High Impact)**
#
# **Competitive Displacement Risk:**
# - **Probability: 55%** - Major players (Microsoft, Google, Salesforce) rapidly improving offerings
# - **Impact:** Pricing pressure, feature differentiation challenges
# - **Mitigation:** Focus on niche specialization, establish patent protections where possible
#
# **Economic Downturn Impact:**
# - **Probability: 40%** - B2B software purchases delayed during economic uncertainty
# - **Impact:** 25-50% reduction in sales velocity
# - **Mitigation:** Develop SMB market entry strategy, offer flexible pricing models
#
# ## Compliance & Regulatory Considerations
#
# ### **Immediate Compliance Requirements:**
# 1. **Data Protection:** GDPR, CCPA, PIPEDA compliance framework ($150K-250K)
# 2. **Industry Standards:** SOC 2 Type II certification ($75K-100K annually)
# 3. **Accessibility:** ADA compliance for customer interfaces ($50K-75K)
# 4. **AI Ethics:** Algorithmic bias testing and documentation ($25K-50K)
#
# ### **Emerging Regulatory Risks:**
# - **EU AI Act:** May require conformity assessments ($100K+)
# - **State-level AI regulations:** Varying requirements across jurisdictions
# - **Industry-specific rules:** Healthcare, finance, government sectors have additional requirements
#
# ## Financial Risk Mitigation Strategies
#
# ### **Risk-Adjusted Financial Model:**
# - **Reduce ROI projection to 100-120%** to account for identified risks
# - **Extend payback period to 4-5 years** for conservative planning
# - **Reserve 25% of budget** ($500K) for risk mitigation and compliance
#
# ### **Staged Investment Approach:**
# - **Phase 1:** $750K for MVP and pilot (6 months)
# - **Phase 2:** $750K for scale-up (conditional on Phase 1 success)
# - **Phase 3:** $500K for market expansion (conditional on proven unit economics)
#
# ### **Key Risk Metrics to Monitor:**
# 1. Customer acquisition cost trends
# 2. AI accuracy rates and escalation frequency
# 3. Regulatory compliance audit results
# 4. Competitive feature gap analysis
# 5. Customer churn rates and satisfaction scores
#
# ## Insurance & Legal Recommendations
#
# **Required Coverage:**
# - **Professional Liability:** $2M minimum for AI-related errors
# - **Cyber Liability:** $5M for data breaches
# - **Directors & Officers:** $3M for management decisions
# - **Estimated annual cost:** $75K-125K
#
# **Legal Structure:**
# - Establish separate subsidiary for AI platform to limit parent company exposure
# - Include AI-specific limitations in customer contracts
# - Implement comprehensive data processing agreements
#
# ## Final Recommendation
#
# **CONDITIONAL PROCEED** with enhanced risk management:
# 1. Reduce initial investment to $1.5M with staged approach
# 2. Adjust ROI expectations to 100-120% over 4 years
# 3. Allocate minimum $400K for risk mitigation and compliance
# 4. Establish monthly risk review processes
# 5. Implement comprehensive insurance coverage
#
# The project remains viable but requires significantly more conservative financial planning and robust risk management to achieve sustainable returns.
#
# ============================================================
# ============================================================
# Response: GraphResult(status=<Status.COMPLETED: 'completed'>, results={'finance_expert': NodeResult(result=AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': "**Financial Assessment: AI Customer Service Platform Investment**\n\n**Initial Analysis:**\n- Investment: $2M\n- 3-year ROI: 150% \n- This translates to $3M net profit over 3 years ($5M total return - $2M investment)\n\n**Key Financial Considerations I Need Clarified:**\n\n**Revenue Model Questions:**\n- What's the breakdown of projected savings vs. new revenue generation?\n- Are these benefits from reduced labor costs, increased customer satisfaction, or expanded service capacity?\n\n**Cost Structure Deep-dive:**\n- Does the $2M include ongoing operational costs (cloud infrastructure, maintenance, updates)?\n- What are the annual licensing/subscription fees?\n- Training and change management costs included?\n\n**Risk-Adjusted Returns:**\n- The 150% ROI assumes best-case scenarios - what's the sensitivity analysis?\n- Break-even timeline?\n- Payback period calculation?\n\n**Comparative Analysis Needed:**\n- How does this compare to incremental improvements to existing systems?\n- What's the NPV using your company's weighted average cost of capital?\n\n**Questions for Technical/Operations Teams:**\n- Integration complexity and potential disruption costs?\n- Scalability factors that could accelerate ROI?\n- Measurable KPIs for tracking actual vs. projected performance?\n\nWould you like me to develop a more detailed financial model once we have these specifics? Also, what's your company's typical hurdle rate for technology investments?"}]}, metrics=EventLoopMetrics(cycle_count=1, tool_metrics={}, cycle_durations=[4.996963739395142], traces=[<strands.telemetry.metrics.Trace object at 0x7f6abc6bb290>], accumulated_usage={'inputTokens': 77, 'outputTokens': 328, 'totalTokens': 405}, accumulated_metrics={'latencyMs': 4978}), state={}, interrupts=None, structured_output=None), execution_time=4997, status=<Status.COMPLETED: 'completed'>, accumulated_usage={'inputTokens': 77, 'outputTokens': 328, 'totalTokens': 405}, accumulated_metrics={'latencyMs': 4978}, execution_count=1, interrupts=[]), 'market_expert': NodeResult(result=AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': "# Market Research Assessment: AI Customer Service Platform\n\n## Market Opportunity Analysis\n\n**Market Size & Growth:**\n- Global AI customer service market valued at $4.2B (2023), projected to reach $16.8B by 2030 (CAGR: 22.1%)\n- 73% of enterprises plan to increase AI customer service investments within 2 years\n- Post-pandemic acceleration: 65% of companies accelerated digital customer service adoption\n\n**Competitive Landscape Insights:**\n- **Established Players:** Zendesk AI, Salesforce Einstein, Microsoft Dynamics 365 AI\n- **Emerging Leaders:** Ada, Intercom Resolution Bot, LivePerson Conversational Cloud\n- **Market Gap:** Mid-market solutions with industry-specific customization remain underserved\n\n## Customer Demand Validation\n\n**Pain Points Driving Adoption:**\n- 67% of customers expect 24/7 support availability\n- Average customer service labor costs increased 23% post-2022\n- 45% of support tickets are repetitive, ideal for AI automation\n- Customer satisfaction drops 35% during peak volume periods\n\n**Adoption Readiness Indicators:**\n- 78% of businesses report readiness to adopt AI customer service\n- Primary drivers: cost reduction (89%), improved response times (76%), scalability (71%)\n\n## Critical Market Questions for Finance Team\n\n**Revenue Model Validation:**\n- Are you targeting **cost-displacement** (replacing human agents) or **capacity-expansion** (handling more volume)?\n- **Pricing strategy:** Per-interaction, per-seat, or value-based pricing?\n- **Customer lifetime value:** What's the retention rate assumption for AI service customers?\n\n**Market Timing Risks:**\n- Economic uncertainty may delay e ...
# =============Node execution order:==========================
# ============================================================
# Executed: finance_expert
# Executed: market_expert
# Executed: tech_expert
# Executed: risk_analyst
# =============Graph metrics:=================================
# ============================================================
# Total nodes: 4
# Completed nodes: 4
# Failed nodes: 0
# Execution time: 0ms
# Token usage: {'inputTokens': 2350, 'outputTokens': 2839, 'totalTokens': 5189}
# Financial Advisor:
# ============================================================
# ============================================================
# **Financial Assessment: AI Customer Service Platform Investment**
#
# **Initial Analysis:**
# - Investment: $2M
# - 3-year ROI: 150%
# - This translates to $3M net profit over 3 years ($5M total return - $2M investment)
#
# **Key Financial Considerations I Need Clarified:**
#
# **Revenue Model Questions:**
# - What's the breakdown of projected savings vs. new revenue generation?
# - Are these benefits from reduced labor costs, increased customer satisfaction, or expanded service capacity?
#
# **Cost Structure Deep-dive:**
# - Does the $2M include ongoing operational costs (cloud infrastructure, maintenance, updates)?
# - What are the annual licensing/subscription fees?
# - Training and change management costs included?
#
# **Risk-Adjusted Returns:**
# - The 150% ROI assumes best-case scenarios - what's the sensitivity analysis?
# - Break-even timeline?
# - Payback period calculation?
#
# **Comparative Analysis Needed:**
# - How does this compare to incremental improvements to existing systems?
# - What's the NPV using your company's weighted average cost of capital?
#
# **Questions for Technical/Operations Teams:**
# - Integration complexity and potential disruption costs?
# - Scalability factors that could accelerate ROI?
# - Measurable KPIs for tracking actual vs. projected performance?
#
# Would you like me to develop a more detailed financial model once we have these specifics? Also, what's your company's typical hurdle rate for technology investments?
#
#
#
# Technical Expert:
# ============================================================
# ============================================================
# # Technical Architecture Assessment: AI Customer Service Platform
#
# ## **Technical Feasibility Analysis**
#
# ### **System Architecture Viability**
# ✅ **Highly Feasible** - Modern AI customer service platforms are well-established technology
# - Proven frameworks available (Microsoft Bot Framework, Google Dialogflow, Amazon Lex)
# - Mature NLP/ML libraries and cloud services
# - Established integration patterns with existing CRM/ticketing systems
#
# ### **Implementation Complexity Assessment**
#
# **Phase 1: Foundation (Months 1-6)**
# - **Medium Complexity**: Core platform deployment
# - Integration with existing customer databases and CRM systems
# - Basic chatbot/voice assistant implementation
# - Initial training data preparation and model training
#
# **Phase 2: Advanced Features (Months 7-12)**
# - **High Complexity**: Advanced AI capabilities
# - Sentiment analysis and emotional intelligence
# - Multi-language support and localization
# - Complex workflow automation and escalation logic
#
# **Phase 3: Optimization (Months 13-18)**
# - **Medium Complexity**: Performance tuning and scaling
# - Advanced analytics and reporting dashboards
# - Continuous learning and model refinement
#
# ## **Critical Technical Risks & Mitigation**
#
# ### **High-Risk Areas:**
# 1. **Data Quality & Integration**
#    - **Risk**: Poor data quality → AI performance degradation
#    - **Mitigation**: Comprehensive data audit, cleansing pipeline, gradual rollout
#
# 2. **Legacy System Integration**
#    - **Risk**: Complex integrations → extended timeline/budget overruns
#    - **Mitigation**: API-first approach, middleware layer, thorough system mapping
#
# 3. **AI Model Performance**
#    - **Risk**: Inaccurate responses → customer satisfaction decline
#    - **Mitigation**: Extensive testing phases, human-in-the-loop validation, gradual automation
#
# ### **Medium-Risk Areas:**
# - Scalability bottlenecks during peak loads
# - Compliance and data privacy requirements
# - Change management and staff training
#
# ## **Technical Questions for Finance Team:**
#
# 1. **Infrastructure Costs**: Does your $2M include cloud infrastructure scaling costs? AI platforms can have variable compute costs based on usage.
#
# 2. **Integration Budget**: Have you allocated 20-30% of budget for system integrations? This is typically the most unpredictable cost component.
#
# 3. **Ongoing Maintenance**: Annual technical maintenance typically runs 15-20% of initial platform cost - is this factored into your ROI model?
#
# ## **Recommendations:**
#
# ✅ **Proceed with Confidence** - Technology risk is manageable with proper planning
#
# **Success Factors:**
# - Start with pilot deployment (limited customer segment)
# - Implement robust monitoring and fallback mechanisms
# - Plan for 6-month technical validation period before full rollout
# - Ensure dedicated technical team for first 18 months
#
# **Timeline Reality Check:**
# The 3-year ROI projection aligns well with typical AI platform maturation curves. Most organizations see break-even by months 18-24.
#
# What's your current technical infrastructure maturity level, and do you have in-house AI/ML expertise?
#
#
#
# Market Researcher:
# ============================================================
# ============================================================
# # Market Research Assessment: AI Customer Service Platform
#
# ## Market Opportunity Analysis
#
# **Market Size & Growth:**
# - Global AI customer service market valued at $4.2B (2023), projected to reach $16.8B by 2030 (CAGR: 22.1%)
# - 73% of enterprises plan to increase AI customer service investments within 2 years
# - Post-pandemic acceleration: 65% of companies accelerated digital customer service adoption
#
# **Competitive Landscape Insights:**
# - **Established Players:** Zendesk AI, Salesforce Einstein, Microsoft Dynamics 365 AI
# - **Emerging Leaders:** Ada, Intercom Resolution Bot, LivePerson Conversational Cloud
# - **Market Gap:** Mid-market solutions with industry-specific customization remain underserved
#
# ## Customer Demand Validation
#
# **Pain Points Driving Adoption:**
# - 67% of customers expect 24/7 support availability
# - Average customer service labor costs increased 23% post-2022
# - 45% of support tickets are repetitive, ideal for AI automation
# - Customer satisfaction drops 35% during peak volume periods
#
# **Adoption Readiness Indicators:**
# - 78% of businesses report readiness to adopt AI customer service
# - Primary drivers: cost reduction (89%), improved response times (76%), scalability (71%)
#
# ## Critical Market Questions for Finance Team
#
# **Revenue Model Validation:**
# - Are you targeting **cost-displacement** (replacing human agents) or **capacity-expansion** (handling more volume)?
# - **Pricing strategy:** Per-interaction, per-seat, or value-based pricing?
# - **Customer lifetime value:** What's the retention rate assumption for AI service customers?
#
# **Market Timing Risks:**
# - Economic uncertainty may delay enterprise software purchases
# - **Regulatory concerns:** EU AI Act and similar regulations could impact deployment
# - **Competition intensification:** Major players rapidly improving offerings
#
# **Go-to-Market Feasibility:**
# - What's your **target customer segment**? (SMB, Mid-market, Enterprise)
# - **Sales cycle length** for AI solutions averages 8-14 months
# - **Customer acquisition cost** in this space typically $15K-50K per enterprise client
#
# ## Recommendation for Financial Model Refinement
#
# The 150% ROI projection needs market-reality testing:
# - **Conservative scenario:** Account for 18-month longer adoption curves
# - **Customer churn risk:** 25-30% first-year churn is typical for new AI platforms
# - **Feature parity catch-up:** Budget for competitive feature development
#
# **Next Steps:**
# 1. Validate target customer willingness-to-pay through direct interviews
# 2. Analyze competitor pricing and feature differentiation
# 3. Assess regulatory compliance costs for your target markets
#
# Would you like me to dive deeper into any specific market segment or competitive analysis?

# %% [markdown]
# ### Branching with conditions
#
# Let's create an agent graph that would classify the request and depending on conditions we define in the code - will route the request either to technical or business agent.
#
# Take a close look on differences between the node execution order and number of nodes executed in this graph based on two different prompts.
#
# <div style="text-align:left">
#     <img src="images/conditional.png" width="55%" />
# </div>

# %%
#Initialize an agent with agent_graph capability
from strands.multiagent import GraphBuilder

mesh_agent = Agent()
# Create specialized agents

classifier = Agent(name="classifier", system_prompt="You are an agent responsible for classification of the report request, return only Technical or Business clasification.")
technical_report = Agent(name="technical_expert", system_prompt="You are a technical expert htat focuses on providing short summary from technical perspective")
business_report = Agent(name="business_expert", system_prompt="You are a business expert that focuses on providing short summary from business perspective")

# Build the graph
builder = GraphBuilder()

# Add nodes
builder.add_node(classifier, "classifier")
builder.add_node(technical_report, "technical_report")
builder.add_node(business_report, "business_report")

def is_technical(state):
    classifier_result = state.results.get("classifier")
    if not classifier_result:
        return False
    result_text = str(classifier_result.result)
    return "technical" in result_text.lower()

def is_business(state):
    classifier_result = state.results.get("classifier")
    if not classifier_result:
        return False
    result_text = str(classifier_result.result)
    return "business" in result_text.lower()

# Add edges (dependencies)
builder.add_edge("classifier", "technical_report", condition=is_technical)
builder.add_edge("classifier", "business_report", condition=is_business)

# Set entry points (optional - will be auto-detected if not specified)
builder.set_entry_point("classifier")

# Build the graph
graph = builder.build()

print("============================================================")
print("============================================================")

#Execute task on newly built graph
result = graph("Provide report on technical aspect of working from home, outline things to consider and key risk factors")
print("\n")
print("============================================================")
print("============================================================")

print(f"Response: {result}")

print("=============Node execution order:==========================")
print("============================================================")

# See which nodes were executed and in what order
for node in result.execution_order:
    print(f"Executed: {node.node_id}")

print("=============Graph metrics:=================================")
print("============================================================")


# Get performance metrics
print(f"Total nodes: {result.total_nodes}")
print(f"Completed nodes: {result.completed_nodes}")
print(f"Failed nodes: {result.failed_nodes}")
print(f"Execution time: {result.execution_time}ms")
print(f"Token usage: {result.accumulated_usage}")

# Get results from specific nodes

print("Classifier:")
print("============================================================")
print("============================================================")
print(result.results["classifier"].result)
print("\n")

#Execute task on newly built graph
result = graph("Provide report on business impact of working from home, outline things to consider and key risk factors")
print("\n")
print("============================================================")
print("============================================================")

print(f"Response: {result}")

print("=============Node execution order:==========================")
print("============================================================")

# See which nodes were executed and in what order
for node in result.execution_order:
    print(f"Executed: {node.node_id}")

print("=============Graph metrics:=================================")
print("============================================================")


# Get performance metrics
print(f"Total nodes: {result.total_nodes}")
print(f"Completed nodes: {result.completed_nodes}")
print(f"Failed nodes: {result.failed_nodes}")
print(f"Execution time: {result.execution_time}ms")
print(f"Token usage: {result.accumulated_usage}")

# Get results from specific nodes

print("Classifier:")
print("============================================================")
print("============================================================")
print(result.results["classifier"].result)
print("\n")
# Out:
# Graph without execution limits may run indefinitely if cycles exist
# ============================================================
# ============================================================
# Technical# Technical Report: Working From Home Infrastructure
#
# ## Key Technical Considerations
#
# ### Network Infrastructure
# - **Bandwidth Requirements**: Minimum 25 Mbps download/5 Mbps upload for video conferencing
# - **Connection Stability**: Wired ethernet preferred over Wi-Fi for critical work
# - **Backup Connectivity**: Mobile hotspot or secondary ISP for redundancy
#
# ### Security Architecture
# - **VPN Implementation**: Enterprise-grade VPN with split tunneling capabilities
# - **Endpoint Protection**: Multi-layered security (antivirus, EDR, firewall)
# - **Network Segmentation**: Isolated work network from personal devices
#
# ### Hardware Specifications
# - **Compute Power**: Minimum 8GB RAM, SSD storage for performance
# - **Display Setup**: Dual monitors recommended for productivity
# - **Peripherals**: Quality webcam, noise-canceling headset, ergonomic peripherals
#
# ## Critical Risk Factors
#
# ### Security Vulnerabilities
# - **Unsecured Home Networks**: Default router configurations, weak passwords
# - **Shadow IT**: Unapproved cloud services and applications
# - **Physical Security**: Device theft, screen visibility, uncontrolled access
#
# ### Technical Reliability Issues
# - **Single Points of Failure**: Power outages, ISP downtime, hardware failures
# - **Performance Degradation**: Network congestion during peak hours
# - **Compatibility Problems**: Software licensing, legacy system access
#
# ### Data Management Risks
# - **Backup Failures**: Inadequate local/cloud backup strategies
# - **Sync Issues**: Version conflicts, data loss during synchronization
# - **Compliance Gaps**: GDPR, HIPAA violations due to improper data handling
#
# ## Mitigation Strategies
# - Implement centralized device management (MDM/MAM)
# - Regular security awareness training
# - Standardized home office technology packages
# - 24/7 technical support infrastructure
#
# ============================================================
# ============================================================
# Response: GraphResult(status=<Status.COMPLETED: 'completed'>, results={'classifier': NodeResult(result=AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': 'Technical'}]}, metrics=EventLoopMetrics(cycle_count=1, tool_metrics={}, cycle_durations=[1.5064845085144043], traces=[<strands.telemetry.metrics.Trace object at 0x7f6aae5a3380>], accumulated_usage={'inputTokens': 46, 'outputTokens': 4, 'totalTokens': 50}, accumulated_metrics={'latencyMs': 1487}), state={}, interrupts=None, structured_output=None), execution_time=1507, status=<Status.COMPLETED: 'completed'>, accumulated_usage={'inputTokens': 46, 'outputTokens': 4, 'totalTokens': 50}, accumulated_metrics={'latencyMs': 1487}, execution_count=1, interrupts=[]), 'technical_report': NodeResult(result=AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': '# Technical Report: Working From Home Infrastructure\n\n## Key Technical Considerations\n\n### Network Infrastructure\n- **Bandwidth Requirements**: Minimum 25 Mbps download/5 Mbps upload for video conferencing\n- **Connection Stability**: Wired ethernet preferred over Wi-Fi for critical work\n- **Backup Connectivity**: Mobile hotspot or secondary ISP for redundancy\n\n### Security Architecture\n- **VPN Implementation**: Enterprise-grade VPN with split tunneling capabilities\n- **Endpoint Protection**: Multi-layered security (antivirus, EDR, firewall)\n- **Network Segmentation**: Isolated work network from personal devices\n\n### Hardware Specifications\n- **Compute Power**: Minimum 8GB RAM, SSD storage for performance\n- **Display Setup**: Dual monitors recommended for productivity\n- **Peripherals**: Quality webcam, noise-canceling headset, ergonomic peripherals\n\n## Critical Risk Factors\n\n### Security Vulnerabilities\n- **Unsecured Home Networks**: Default router configurations, weak passwords\n- **Shadow IT**: Unapproved cloud services and applications\n- **Physical Security**: Device theft, screen visibility, uncontrolled access\n\n### Technical Reliability Issues\n- **Single Points of Failure**: Power outages, ISP downtime, hardware failures\n- **Performance Degradation**: Network congestion during peak hours\n- **Compatibility Problems**: Software licensing, legacy system access\n\n### Data Management Risks\n- **Backup Failures**: Inadequate local/cloud backup strategies\n- **Sync Issues**: Version conflicts, data loss during synchronization\n- **Compliance Gaps**: GDPR, HIPAA violations due to improper data handling\n\n## Mitigation Strategies\n- Implement centralized device management (MDM/MAM)\n- Regular security awareness training\n- Standardized home office technology packages\n- 24/7 technical support infrastructure'}]}, metrics=EventLoopMetrics(cycle_count=1, tool_metrics={}, cycle_durations=[5.8479249477386475], traces=[<strands.telemetry.metrics.Trace object at 0x7f6aae5a3440>], accumulated_usage={'inputTokens': 60, 'outputTokens': 422, 'totalTokens': 482}, accumulated_metrics={'latencyMs': 5830}), state={}, interrupts=None, structured_output=None), execution_time=5848, status=<Status.COMPLETED: 'completed'>, accumulated_usage={'inputTokens': 60, 'outputTokens': 422, 'totalTokens': 482}, accumulated_metrics={'latencyMs': 5830}, execution_count=1, interrupts=[])}, accumulated_usage={'inputTokens': 106, 'outputTokens': 426, 'totalTokens': 532}, accumulated_metrics={'latencyMs': 7317}, execution_count=2, execution_time=0, interrupts=[], total_nodes=3, completed_nodes=2, failed_nodes=0, execution_order=[GraphNode(node_id='classifier', executor=<strands.agent.agent.Agent object at 0x7f6abcd12bd0>, dependencies=set(), execution_status=<Status.COMPLETED: 'completed'>, result=NodeResult(result=AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': 'Technical'}]}, metrics=EventLoopMetrics(cycle_count=1, tool_metrics={}, cycle_durations=[1.5064845085144043], traces=[<strands.telemetry.metrics.Trace object at 0x7f6aae5a3380 ...
# =============Node execution order:==========================
# ============================================================
# Executed: classifier
# Executed: technical_report
# =============Graph metrics:=================================
# ============================================================
# Total nodes: 3
# Completed nodes: 2
# Failed nodes: 0
# Execution time: 0ms
# Token usage: {'inputTokens': 106, 'outputTokens': 426, 'totalTokens': 532}
# Classifier:
# ============================================================
# ============================================================
# Technical
#
#
#
# Business# Business Impact of Working From Home: Executive Summary
#
# ## Key Business Impacts
#
# **Positive Impacts:**
# - **Cost Reduction**: 25-30% savings on office space, utilities, and facilities management
# - **Talent Pool Expansion**: Access to global workforce, reduced geographic constraints
# - **Employee Retention**: 40% improvement in retention rates due to enhanced work-life balance
# - **Productivity Gains**: 13-50% increase reported across knowledge work sectors
#
# **Negative Impacts:**
# - **Collaboration Challenges**: Reduced spontaneous innovation and team cohesion
# - **Management Complexity**: Difficulty monitoring performance and maintaining company culture
# - **Technology Costs**: Increased IT infrastructure and security investments
#
# ## Critical Considerations
#
# 1. **Hybrid Model Implementation**: Balance flexibility with in-person collaboration needs
# 2. **Performance Metrics**: Shift from time-based to outcome-based measurement systems
# 3. **Technology Infrastructure**: Robust cybersecurity, cloud platforms, and communication tools
# 4. **Legal Compliance**: Tax implications, labor laws across jurisdictions, insurance coverage
#
# ## Key Risk Factors
#
# - **Cybersecurity Vulnerabilities**: 300% increase in security breaches with remote work
# - **Employee Isolation**: Mental health impacts affecting long-term productivity
# - **Compliance Risks**: Varying regulations across remote work locations
# - **Competitive Disadvantage**: Loss of company culture and reduced innovation capacity
# - **Data Protection**: Increased exposure of sensitive business information
#
# ## Recommendation
# Implement structured hybrid approach with clear policies, robust technology, and regular performance reviews to maximize benefits while mitigating risks.
#
# ============================================================
# ============================================================
# Response: GraphResult(status=<Status.COMPLETED: 'completed'>, results={'classifier': NodeResult(result=AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': 'Business'}]}, metrics=EventLoopMetrics(cycle_count=2, tool_metrics={}, cycle_durations=[1.5064845085144043, 0.8528649806976318], traces=[<strands.telemetry.metrics.Trace object at 0x7f6aae5a3380>, <strands.telemetry.metrics.Trace object at 0x7f6aae5a2f60>], accumulated_usage={'inputTokens': 118, 'outputTokens': 8, 'totalTokens': 126}, accumulated_metrics={'latencyMs': 2334}), state={}, interrupts=None, structured_output=None), execution_time=853, status=<Status.COMPLETED: 'completed'>, accumulated_usage={'inputTokens': 118, 'outputTokens': 8, 'totalTokens': 126}, accumulated_metrics={'latencyMs': 2334}, execution_count=1, interrupts=[]), 'business_report': NodeResult(result=AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': '# Business Impact of Working From Home: Executive Summary\n\n## Key Business Impacts\n\n**Positive Impacts:**\n- **Cost Reduction**: 25-30% savings on office space, utilities, and facilities management\n- **Talent Pool Expansion**: Access to global workforce, reduced geographic constraints\n- **Employee Retention**: 40% improvement in retention rates due to enhanced work-life balance\n- **Productivity Gains**: 13-50% increase reported across knowledge work sectors\n\n**Negative Impacts:**\n- **Collaboration Challenges**: Reduced spontaneous innovation and team cohesion\n- **Management Complexity**: Difficulty monitoring performance and maintaining company culture\n- **Technology Costs**: Increased IT infrastructure and security investments\n\n## Critical Considerations\n\n1. **Hybrid Model Implementation**: Balance flexibility with in-person collaboration needs\n2. **Performance Metrics**: Shift from time-based to outcome-based measurement systems\n3. **Technology Infrastructure**: Robust cybersecurity, cloud platforms, and communication tools\n4. **Legal Compliance**: Tax implications, labor laws across jurisdictions, insurance coverage\n\n## Key Risk Factors\n\n- **Cybersecurity Vulnerabilities**: 300% increase in security breaches with remote work\n- **Employee Isolation**: Mental health impacts affecting long-term productivity\n- **Compliance Risks**: Varying regulations across remote work locations\n- **Competitive Disadvantage**: Loss of company culture and reduced innovation capacity\n- **Data Protection**: Increased exposure of sensitive business information\n\n## Recommendation\nImplement structured hybrid approach with clear policies, robust technology, and regular performance reviews to maximize benefits while mitigating risks.'}]}, metrics=EventLoopMetrics(cycle_count=1, tool_metrics={}, cycle_durations=[5.393153667449951], traces=[<strands.telemetry.metrics.Trace object at 0x7f6aae5a37a0>], accumulated_usage={'inputTokens': 59, 'outputTokens': 357, 'totalTokens': 416}, accumulated_metrics={'latencyMs': 5374}), state={}, interrupts=None, structured_output=None), execution_time=5393, status=<Status.COMPLETED: 'completed'>, accumulated_usage={'inputTokens': 59, 'outputTokens': 357, 'totalTokens': 416}, accumulated_metrics={'latencyMs': 5374}, execution_count=1, interrupts=[])}, accumulated_usage={'inputTokens': 177, 'outputTokens': 365, 'totalTokens': 542}, accumulated_metrics={'latencyMs': 7708}, execution_count=2, execution_time=0, interrupts=[], total_nodes=3, completed_nodes=2, failed_nodes=0, execution_order=[GraphNode(node_id='classifier', executor=<strands.agent.agent.Agent object at 0x7f6abcd12bd0>, dependencies=set(), execution_status=<Status.COMPLETED: 'completed'>, result=NodeResult(result=AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': 'Business'}]}, metrics=EventLoopMetrics(cycle_count=2, tool_metrics={}, cycle_durations=[1.5064845085144043, 0.8528649806976318], traces=[<strands.telemetry.metrics.Trace object at 0x7f6aae5a ...
# =============Node execution order:==========================
# ============================================================
# Executed: classifier
# Executed: business_report
# =============Graph metrics:=================================
# ============================================================
# Total nodes: 3
# Completed nodes: 2
# Failed nodes: 0
# Execution time: 0ms
# Token usage: {'inputTokens': 177, 'outputTokens': 365, 'totalTokens': 542}
# Classifier:
# ============================================================
# ============================================================
# Business

# %% [markdown]
# ## Key Takeaways and Best Practices
#
#
# ### Best Practices:
#
# **Design for acyclicity:** Ensure your graph has no cycles</p>
# **Use meaningful node IDs:** Choose descriptive names for nodes</p>
# **Validate graph structure:** The builder will check for cycles and validate entry points</p>
# **Handle node failures:** Consider how failures in one node affect the overall workflow</p>
# **Use conditional edges:** For dynamic workflows based on intermediate results</p>
# **Consider parallelism:** Independent branches can execute concurrently</p>
# **Nest multi-agent patterns:** Use Swarms within Graphs for complex workflows</p>
# **Leverage multi-modal inputs:** Use ContentBlocks for rich inputs including images</p>
#
# ## Conclusion
#
# You've now mastered the fundamentals of building multi-agent systems with Strands Agent Graph! You can create sophisticated networks of specialized AI agents that collaborate to solve complex problems.
#
# The key to successful multi-agent systems is:
# - Matching topology to use case
# - Defining clear agent roles and responsibilities
# - Establishing proper communication patterns
# - Managing resources and cleanup effectively
#
# From here, you can build increasingly sophisticated systems for real-world applications in research, content creation, decision-making, customer service, and beyond.
